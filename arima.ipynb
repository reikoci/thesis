# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import accuracy_score, matthews_corrcoef, f1_score, confusion_matrix
from scipy.special import expit, logit

# %%
df = pd.read_csv('fnspid/fnspid_prices_title_sentiment.csv')

# %%
df = df.set_index('date')
df.index = pd.to_datetime(df.index)
stocks_to_remove = ['MMM', 'SBUX', 'SIRI', 'SLB', 'SLV']
df = df[~df['Stock_symbol'].isin(stocks_to_remove)]
indexes = ['EEM' , 'EWJ', 'GDX', 'GLD', 'QQQ', 'SLV', 'USO', 'XLF', 'XLK', 'XLP', 'XLU', 'XLY']
df = df[~df['Stock_symbol'].isin(indexes)]

# %%
from sklearn.preprocessing import StandardScaler

features = ['open', 'high', 'low', 'close', 'volatility', 'volume']
results = []

eps = 1e-6

for stock, df_stock in df.groupby('Stock_symbol'):
    print(f"\n--- Processing {stock} ---")

    df_stock = df_stock.copy()

    df_stock['target_binary'] = (df_stock['movement_percent'] >= 0).astype(int)
    df_stock['target_binary'] = df_stock['target_binary'].shift(-1)
    df_stock['volatility'] = df_stock['close'].pct_change().rolling(window=20).std()

    df_stock.dropna(inplace=True)

    y = df_stock['target_binary'].values
    y_logodds = logit(np.clip(y, eps, 1 - eps))

    X = df_stock[features].values

    train_size = int(len(df_stock) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    y_train, y_test = y_logodds[:train_size], y_logodds[train_size:]

    model = ARIMA(y_train, exog=X_train, order=(1,0,0))
    fit = model.fit()

    y_pred_logodds = fit.predict(start=train_size, end=len(df_stock)-1, exog=X_test)
    y_pred_prob = expit(y_pred_logodds)
    y_pred_class = (y_pred_prob > 0.5).astype(int)

    y_true = df_stock['target_binary'].values[train_size:]

    acc = accuracy_score(y_true, y_pred_class)
    f1 = f1_score(y_true, y_pred_class)
    mcc = matthews_corrcoef(y_true, y_pred_class)
    cm = confusion_matrix(y_true, y_pred_class)

    print(f"Accuracy: {acc:.4f}")
    print(f"MCC: {mcc:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("Confusion Matrix:")
    print(cm)

    results.append({
        'stock': stock,
        'accuracy': acc,
        'f1': f1,
        'mcc': mcc,
        'confusion_matrix': cm
    })

results_df = pd.DataFrame(results)
print("\nSummary of all stocks:")
print(results_df)

mean_metrics = results_df.drop(columns=["stock"]).mean(numeric_only=True).to_dict()
for metric_name, value in mean_metrics.items():
    print(f"{metric_name}: {value:.4f}")
# Out:
# --- Processing AAL ---
# Accuracy: 0.5258
# MCC: 0.0479
# F1 Score: 0.6212
# Confusion Matrix:
# [[ 61 157]
#  [ 54 173]]
#
# --- Processing ABBV ---
# Accuracy: 0.5213
# MCC: -0.0122
# F1 Score: 0.6778
# Confusion Matrix:
# [[  8 203]
#  [ 10 224]]
#
# --- Processing ACN ---
# Accuracy: 0.5416
# MCC: 0.0799
# F1 Score: 0.6208
# Confusion Matrix:
# [[ 74 143]
#  [ 61 167]]
#
# --- Processing ADBE ---
# Accuracy: 0.4989
# MCC: -0.0597
# F1 Score: 0.6585
# Confusion Matrix:
# [[  7 210]
#  [ 13 215]]
#
# --- Processing AEO ---
# Accuracy: 0.5371
# MCC: -0.0350
# F1 Score: 0.6944
# Confusion Matrix:
# [[  5 197]
#  [  9 234]]
#
# --- Processing AIG ---
# Accuracy: 0.5011
# MCC: -0.0032
# F1 Score: 0.5356
# Confusion Matrix:
# [[ 95 110]
#  [112 128]]
#
# --- Processing ALK ---
# Accuracy: 0.5056
# MCC: 0.0137
# F1 Score: 0.6636
# Confusion Matrix:
# [[  8 213]
#  [  7 217]]
#
# --- Processing AMGN ---
# Accuracy: 0.5079
# MCC: 0.0042
# F1 Score: 0.1205
# Confusion Matrix:
# [[211  15]
#  [204  15]]
#
# --- Processing AMT ---
# Accuracy: 0.5056
# MCC: 0.0205
# F1 Score: 0.6259
# Confusion Matrix:
# [[ 41 183]
#  [ 37 184]]
#
# --- Processing BABA ---
# Accuracy: 0.5236
# MCC: 0.0041
# F1 Score: 0.3576
# Confusion Matrix:
# [[174  72]
#  [140  59]]
#
# --- Processing BHP ---
# Accuracy: 0.5034
# MCC: 0.0094
# F1 Score: 0.4920
# Confusion Matrix:
# [[117  98]
#  [123 107]]
#
# --- Processing BIDU ---
# Accuracy: 0.4742
# MCC: 0.0085
# F1 Score: 0.5806
# Confusion Matrix:
# [[ 49 195]
#  [ 39 162]]
#
# --- Processing BIIB ---
# Accuracy: 0.5258
# MCC: 0.0793
# F1 Score: 0.6157
# Confusion Matrix:
# [[ 65 165]
#  [ 46 169]]
#
# --- Processing BSX ---
# Accuracy: 0.5079
# MCC: 0.0079
# F1 Score: 0.5521
# Confusion Matrix:
# [[ 91 119]
#  [100 135]]
#
# --- Processing BX ---
# Accuracy: 0.5124
# MCC: 0.0122
# F1 Score: 0.5913
# Confusion Matrix:
# [[ 71 143]
#  [ 74 157]]
#
# --- Processing CAT ---
# Accuracy: 0.5034
# MCC: 0.0017
# F1 Score: 0.5424
# Confusion Matrix:
# [[ 93 121]
#  [100 131]]
#
# --- Processing CI ---
# Accuracy: 0.4764
# MCC: 0.0020
# F1 Score: 0.3003
# Confusion Matrix:
# [[162  42]
#  [191  50]]
#
# --- Processing CMCSA ---
# Accuracy: 0.4921
# MCC: -0.0899
# F1 Score: 0.6534
# Confusion Matrix:
# [[  6 211]
#  [ 15 213]]
#
# --- Processing CMG ---
# Accuracy: 0.5011
# MCC: -0.0019
# F1 Score: 0.5336
# Confusion Matrix:
# [[ 96 105]
#  [117 127]]
#
# --- Processing COP ---
# Accuracy: 0.4944
# MCC: 0.0013
# F1 Score: 0.4094
# Confusion Matrix:
# [[142  72]
#  [153  78]]
#
# --- Processing COST ---
# Accuracy: 0.5393
# MCC: 0.0197
# F1 Score: 0.6812
# Confusion Matrix:
# [[ 21 183]
#  [ 22 219]]
#
# --- Processing CRM ---
# Accuracy: 0.4831
# MCC: -0.0533
# F1 Score: 0.6034
# Confusion Matrix:
# [[ 40 179]
#  [ 51 175]]
#
# --- Processing CSX ---
# Accuracy: 0.4876
# MCC: -0.0484
# F1 Score: 0.6556
# Confusion Matrix:
# [[  0 227]
#  [  1 217]]
#
# --- Processing D ---
# Accuracy: 0.5146
# MCC: 0.0270
# F1 Score: 0.6044
# Confusion Matrix:
# [[ 64 156]
#  [ 60 165]]
#
# --- Processing DB ---
# Accuracy: 0.4809
# MCC: -0.0697
# F1 Score: 0.5666
# Confusion Matrix:
# [[ 63 139]
#  [ 92 151]]
#
# --- Processing DE ---
# Accuracy: 0.4652
# MCC: -0.0674
# F1 Score: 0.4758
# Confusion Matrix:
# [[ 99 107]
#  [131 108]]
#
# --- Processing DFS ---
# Accuracy: 0.5146
# MCC: 0.0425
# F1 Score: 0.6656
# Confusion Matrix:
# [[ 14 206]
#  [ 10 215]]
#
# --- Processing DHI ---
# Accuracy: 0.5169
# MCC: -0.0133
# F1 Score: 0.6423
# Confusion Matrix:
# [[ 37 170]
#  [ 45 193]]
#
# --- Processing DHR ---
# Accuracy: 0.5146
# MCC: 0.0159
# F1 Score: 0.6677
# Confusion Matrix:
# [[ 12 205]
#  [ 11 217]]
#
# --- Processing DISH ---
# Accuracy: 0.4809
# MCC: 0.0258
# F1 Score: 0.6280
# Confusion Matrix:
# [[ 19 217]
#  [ 14 195]]
#
# --- Processing DPZ ---
# Accuracy: 0.5146
# MCC: 0.0302
# F1 Score: 0.5846
# Confusion Matrix:
# [[ 77 145]
#  [ 71 152]]
#
# --- Processing DUK ---
# Accuracy: 0.5191
# MCC: 0.0192
# F1 Score: 0.6571
# Confusion Matrix:
# [[ 26 189]
#  [ 25 205]]
#
# --- Processing EA ---
# Accuracy: 0.5124
# MCC: 0.0001
# F1 Score: 0.6365
# Confusion Matrix:
# [[ 38 176]
#  [ 41 190]]
#
# --- Processing EBAY ---
# Accuracy: 0.5191
# MCC: 0.0637
# F1 Score: 0.6285
# Confusion Matrix:
# [[ 50 177]
#  [ 37 181]]
#
# --- Processing ENB ---
# Accuracy: 0.5011
# MCC: 0.0005
# F1 Score: 0.5595
# Confusion Matrix:
# [[ 82 139]
#  [ 83 141]]
#
# --- Processing EOG ---
# Accuracy: 0.5146
# MCC: 0.0317
# F1 Score: 0.3684
# Confusion Matrix:
# [[166  57]
#  [159  63]]
#
# --- Processing FDX ---
# Accuracy: 0.4921
# MCC: -0.0039
# F1 Score: 0.6103
# Confusion Matrix:
# [[ 42 185]
#  [ 41 177]]
#
# --- Processing FSLR ---
# Accuracy: 0.4944
# MCC: 0.0079
# F1 Score: 0.1758
# Confusion Matrix:
# [[196  22]
#  [203  24]]
#
# --- Processing GE ---
# Accuracy: 0.4809
# MCC: -0.0308
# F1 Score: 0.4809
# Confusion Matrix:
# [[107  96]
#  [135 107]]
#
# --- Processing GILD ---
# Accuracy: 0.4966
# MCC: 0.0034
# F1 Score: 0.3812
# Confusion Matrix:
# [[152  65]
#  [159  69]]
#
# --- Processing GME ---
# Accuracy: 0.5371
# MCC: 0.0801
# F1 Score: 0.5463
# Confusion Matrix:
# [[115 120]
#  [ 86 124]]
#
# --- Processing GS ---
# Accuracy: 0.4989
# MCC: -0.0115
# F1 Score: 0.1832
# Confusion Matrix:
# [[197  27]
#  [196  25]]
#
# --- Processing GSK ---
# Accuracy: 0.5281
# MCC: 0.0926
# F1 Score: 0.6379
# Confusion Matrix:
# [[ 50 178]
#  [ 32 185]]
#
# --- Processing HAL ---
# Accuracy: 0.4899
# MCC: -0.0112
# F1 Score: 0.4556
# Confusion Matrix:
# [[123  88]
#  [139  95]]
#
# --- Processing HPQ ---
# Accuracy: 0.4831
# MCC: -0.0321
# F1 Score: 0.5756
# Confusion Matrix:
# [[ 59 166]
#  [ 64 156]]
#
# --- Processing HUM ---
# Accuracy: 0.4787
# MCC: -0.0353
# F1 Score: 0.4450
# Confusion Matrix:
# [[120  92]
#  [140  93]]
#
# --- Processing KMB ---
# Accuracy: 0.5416
# MCC: 0.0882
# F1 Score: 0.6304
# Confusion Matrix:
# [[ 67 153]
#  [ 51 174]]
#
# --- Processing KO ---
# Accuracy: 0.5438
# MCC: 0.0648
# F1 Score: 0.6910
# Confusion Matrix:
# [[ 15 193]
#  [ 10 227]]
#
# --- Processing KSS ---
# Accuracy: 0.4719
# MCC: -0.0102
# F1 Score: 0.6191
# Confusion Matrix:
# [[ 19 217]
#  [ 18 191]]
#
# --- Processing MRK ---
# Accuracy: 0.4674
# MCC: 0.0863
# F1 Score: 0.0706
# Confusion Matrix:
# [[199   2]
#  [235   9]]
#
# --- Processing MS ---
# Accuracy: 0.4764
# MCC: -0.0409
# F1 Score: 0.5053
# Confusion Matrix:
# [[ 93 139]
#  [ 94 119]]
#
# --- Processing MU ---
# Accuracy: 0.4787
# MCC: -0.0197
# F1 Score: 0.5639
# Confusion Matrix:
# [[ 63 172]
#  [ 60 150]]
#
# --- Processing NEE ---
# Accuracy: 0.4966
# MCC: -0.0212
# F1 Score: 0.6543
# Confusion Matrix:
# [[  9 213]
#  [ 11 212]]
#
# --- Processing NEM ---
# Accuracy: 0.5034
# MCC: 0.0250
# F1 Score: 0.5443
# Confusion Matrix:
# [[ 92 146]
#  [ 75 132]]
#
# --- Processing NKE ---
# Accuracy: 0.5124
# MCC: 0.0335
# F1 Score: 0.5703
# Confusion Matrix:
# [[ 84 144]
#  [ 73 144]]
#
# --- Processing NOC ---
# Accuracy: 0.5011
# MCC: 0.0030
# F1 Score: 0.5022
# Confusion Matrix:
# [[111 105]
#  [117 112]]
#
# --- Processing NVS ---
# Accuracy: 0.5124
# MCC: 0.0189
# F1 Score: 0.5737
# Confusion Matrix:
# [[ 82 135]
#  [ 82 146]]
#
# --- Processing ORCL ---
# Accuracy: 0.5326
# MCC: 0.0718
# F1 Score: 0.5229
# Confusion Matrix:
# [[123  86]
#  [122 114]]
#
# --- Processing OXY ---
# Accuracy: 0.5416
# MCC: 0.0848
# F1 Score: 0.5467
# Confusion Matrix:
# [[118 111]
#  [ 93 123]]
#
# --- Processing PANW ---
# Accuracy: 0.5011
# MCC: -0.0227
# F1 Score: 0.6092
# Confusion Matrix:
# [[ 50 163]
#  [ 59 173]]
#
# --- Processing PBR ---
# Accuracy: 0.4899
# MCC: -0.0442
# F1 Score: 0.5676
# Confusion Matrix:
# [[ 69 136]
#  [ 91 149]]
#
# --- Processing PEP ---
# Accuracy: 0.5281
# MCC: 0.0545
# F1 Score: 0.6749
# Confusion Matrix:
# [[ 17 198]
#  [ 12 218]]
#
# --- Processing PXD ---
# Accuracy: 0.4831
# MCC: -0.0100
# F1 Score: 0.1353
# Confusion Matrix:
# [[197  18]
#  [212  18]]
#
# --- Processing QCOM ---
# Accuracy: 0.5213
# MCC: 0.0433
# F1 Score: 0.4892
# Confusion Matrix:
# [[130  92]
#  [121 102]]
#
# --- Processing SPWR ---
# Accuracy: 0.4742
# MCC: -0.0382
# F1 Score: 0.4868
# Confusion Matrix:
# [[100 144]
#  [ 90 111]]
#
# --- Processing T ---
# Accuracy: 0.5213
# MCC: 0.0403
# F1 Score: 0.6656
# Confusion Matrix:
# [[ 20 197]
#  [ 16 212]]
#
# --- Processing TJX ---
# Accuracy: 0.5146
# MCC: 0.0281
# F1 Score: 0.5304
# Confusion Matrix:
# [[107 108]
#  [108 122]]
#
# --- Processing TM ---
# Accuracy: 0.5056
# MCC: 0.0084
# F1 Score: 0.5319
# Confusion Matrix:
# [[100 114]
#  [106 125]]
#
# --- Processing TMUS ---
# Accuracy: 0.5213
# MCC: 0.0991
# F1 Score: 0.3446
# Confusion Matrix:
# [[176  33]
#  [180  56]]
#
# --- Processing TRV ---
# Accuracy: 0.5236
# MCC: 0.0374
# F1 Score: 0.6502
# Confusion Matrix:
# [[ 36 180]
#  [ 32 197]]
#
# --- Processing TSM ---
# Accuracy: 0.4854
# MCC: 0.0110
# F1 Score: 0.5588
# Confusion Matrix:
# [[ 71 172]
#  [ 57 145]]
#
# --- Processing TSN ---
# Accuracy: 0.4921
# MCC: 0.0005
# F1 Score: 0.5846
# Confusion Matrix:
# [[ 60 170]
#  [ 56 159]]
#
# --- Processing TXN ---
# Accuracy: 0.5371
# MCC: 0.0767
# F1 Score: 0.5744
# Confusion Matrix:
# [[100 124]
#  [ 82 139]]
#
# --- Processing USB ---
# Accuracy: 0.4809
# MCC: -0.0201
# F1 Score: 0.6131
# Confusion Matrix:
# [[ 31 199]
#  [ 32 183]]
#
# --- Processing V ---
# Accuracy: 0.4831
# MCC: -0.1114
# F1 Score: 0.6338
# Confusion Matrix:
# [[ 16 196]
#  [ 34 199]]
#
# --- Processing VRTX ---
# Accuracy: 0.5124
# MCC: 0.0485
# F1 Score: 0.5102
# Confusion Matrix:
# [[115  75]
#  [142 113]]
#
# --- Processing WBA ---
# Accuracy: 0.4719
# MCC: -0.0465
# F1 Score: 0.5253
# Confusion Matrix:
# [[ 80 152]
#  [ 83 130]]
#
# --- Processing WDC ---
# Accuracy: 0.4899
# MCC: -0.0551
# F1 Score: 0.6502
# Confusion Matrix:
# [[  7 215]
#  [ 12 211]]
#
# --- Processing WFC ---
# Accuracy: 0.5079
# MCC: 0.0300
# F1 Score: 0.6380
# Confusion Matrix:
# [[ 33 191]
#  [ 28 193]]
#
# Summary of all stocks:
#    stock  accuracy        f1       mcc         confusion_matrix
# 0    AAL  0.525843  0.621185  0.047882   [[61, 157], [54, 173]]
# 1   ABBV  0.521348  0.677761 -0.012217    [[8, 203], [10, 224]]
# 2    ACN  0.541573  0.620818  0.079884   [[74, 143], [61, 167]]
# 3   ADBE  0.498876  0.658499 -0.059735    [[7, 210], [13, 215]]
# 4    AEO  0.537079  0.694362 -0.035038     [[5, 197], [9, 234]]
# ..   ...       ...       ...       ...                      ...
# 74     V  0.483146  0.633758 -0.111417   [[16, 196], [34, 199]]
# 75  VRTX  0.512360  0.510158  0.048467  [[115, 75], [142, 113]]
# 76   WBA  0.471910  0.525253 -0.046496   [[80, 152], [83, 130]]
# 77   WDC  0.489888  0.650231 -0.055102    [[7, 215], [12, 211]]
# 78   WFC  0.507865  0.638017  0.029983   [[33, 191], [28, 193]]
#
# [79 rows x 5 columns]
# accuracy: 0.5043
# f1: 0.5435
# mcc: 0.0087
