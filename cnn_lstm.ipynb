# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
from sklearn.metrics import accuracy_score, matthews_corrcoef, f1_score, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

# %%
import os
import random
import tensorflow as tf

seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
tf.config.experimental.enable_op_determinism()

# %%
df = pd.read_csv('fnspid_prices_title_sentiment.csv')
df = df.set_index('date')
df.index = pd.to_datetime(df.index)
stocks_to_remove = ['MMM', 'SBUX', 'SIRI', 'SLB', 'SLV', 'EEM' , 'EWJ', 'GDX', 'GLD', 'QQQ', 'SLV', 'USO', 'XLF', 'XLK', 'XLP', 'XLU', 'XLY']
df = df[~df['Stock_symbol'].isin(stocks_to_remove)]

# %%
df['target_binary'] = (df['movement_percent'] >= 0).astype(int)
df['target_binary'] = df['target_binary'].shift(-1)
df.dropna(inplace=True)

# %%
def sequences(df: DataFrame, window_size: int, feature_cols: list, target: str):
    X, y = [], []

    features = df[feature_cols].to_numpy()
    y_vals = df[target].to_numpy()

    for i in range(len(df) - window_size):
        X.append(features[i:i + window_size])
        y.append(y_vals[i + window_size])

    return np.array(X), np.array(y)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, matthews_corrcoef, confusion_matrix, roc_auc_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# === PARAMETERS ===
window_size = 20
feature_cols = ['open_logret', 'high_logret', 'low_logret', 'close_logret', 'volume_logret']
target = 'target_binary'
l2_value = 1e-4
batch_size = 8
epochs = 50
learning_rate = 0.001

# Results dataframe
results = []

# === LOOP THROUGH EACH STOCK ===
for symbol in df['Stock_symbol'].unique():
    print(f"\n{'='*40}\nTraining model for: {symbol}\n{'='*40}")

    # Subset dataframe
    df_symbol = df[df['Stock_symbol'] == symbol].copy()
    price_cols = ['open', 'high', 'low', 'close', 'volume']
    for col in price_cols:
      df_symbol[f'{col}_logret'] = np.log(df_symbol[col]) - np.log(df_symbol[col].shift(1))
    df_symbol.dropna(inplace=True)

    # Define time splits
    train = df_symbol.loc['2014-01-01':'2021-03-29']
    val = df_symbol.loc['2021-03-30':'2022-07-28']
    test = df_symbol.loc['2022-07-29':'2023-12-01']

    # Skip if insufficient data
    if len(train) < window_size * 2 or len(test) < window_size:
        print(f"Not enough data for {symbol}, skipping.")
        continue

    # Create sequences (your sequences() function should return numpy arrays)
    X_train, y_train = sequences(train, window_size=window_size, feature_cols=feature_cols, target=target)
    X_val, y_val = sequences(val, window_size=window_size, feature_cols=feature_cols, target=target)
    X_test, y_test = sequences(test, window_size=window_size, feature_cols=feature_cols, target=target)

    X_train = np.array(X_train); y_train = np.array(y_train)
    X_val = np.array(X_val); y_val = np.array(y_val)
    X_test = np.array(X_test); y_test = np.array(y_test)

    # Replace NaNs and normalize
    for X in [X_train, X_val, X_test]:
        np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0, copy=False)

    mean = np.mean(X_train, axis=(0,1))
    std = np.std(X_train, axis=(0,1))
    std[std == 0] = 1e-8

    # X_train_norm = (X_train - mean) / std
    # X_val_norm = (X_val - mean) / std
    # X_test_norm = (X_test - mean) / std

    # Print class distribution for test
    unique, counts = np.unique(y_test, return_counts=True)
    dist = dict(zip(unique, counts))
    total = counts.sum()
    pct_0 = 100 * dist.get(0, 0) / total
    pct_1 = 100 * dist.get(1, 0) / total
    print(f"Test class distribution: 0s={pct_0:.2f}%, 1s={pct_1:.2f}%")

    # === Model ===
    model = Sequential([
        Input(shape=(window_size, len(feature_cols))),
        Conv1D(filters=16, kernel_size=3, strides=1, activation='relu', padding='same'),
        BatchNormalization(),
        Conv1D(filters=8, kernel_size=3, strides=1, activation='relu', padding='same'),
        BatchNormalization(),
        LSTM(16),
        Dropout(0.1),
        Dense(16, activation='relu'),
        Dropout(0.2),
        Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_value))
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC', 'accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # === Train ===
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=0
    )

    # === Evaluation ===
    y_val_pred_prob = model.predict(X_val)
    y_val_pred = (y_val_pred_prob > 0.5).astype(int)

    y_test_pred_prob = model.predict(X_test)
    y_test_pred = (y_test_pred_prob > 0.5).astype(int)

    # Validation metrics
    val_auc = roc_auc_score(y_val, y_val_pred_prob)
    val_f1 = f1_score(y_val, y_val_pred)
    val_mcc = matthews_corrcoef(y_val, y_val_pred)

    # Test metrics
    test_auc = roc_auc_score(y_test, y_test_pred_prob)
    test_f1 = f1_score(y_test, y_test_pred)
    test_mcc = matthews_corrcoef(y_test, y_test_pred)
    test_acc = np.mean(y_test_pred.flatten() == y_test.flatten())
    test_cm = confusion_matrix(y_test, y_test_pred)

    print(f"[{symbol}] Test AUC: {test_auc:.4f} | F1: {test_f1:.4f} | MCC: {test_mcc:.4f} | ACC: {test_acc:.4f}")
    print(f"Confusion matrix:\n{test_cm}\n")

    # Save results
    results.append({
        'Symbol': symbol,
        'Val_AUC': val_auc,
        'Val_F1': val_f1,
        'Val_MCC': val_mcc,
        'Test_AUC': test_auc,
        'Test_F1': test_f1,
        'Test_MCC': test_mcc,
        'Test_ACC': test_acc,
        'Test_0%': pct_0,
        'Test_1%': pct_1
    })

# === SAVE ALL RESULTS ===
results_df = pd.DataFrame(results)
results_df.to_csv('model_results_per_stock.csv', index=False)
print("\n=== Summary of all stocks ===")
print(results_df.sort_values('Test_AUC', ascending=False))
# Out:
# ========================================
# Training model for: AAL
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [AAL] Test AUC: 0.5674 | F1: 0.6032 | MCC: 0.0510 | ACC: 0.5298
# Confusion matrix:
# [[ 55  99]
#  [ 51 114]]
#
#
# ========================================
# Training model for: ABBV
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ABBV] Test AUC: 0.5424 | F1: 0.6819 | MCC: 0.0359 | ACC: 0.5204
# Confusion matrix:
# [[  2 152]
#  [  1 164]]
#
#
# ========================================
# Training model for: ACN
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ACN] Test AUC: 0.4994 | F1: 0.6805 | MCC: 0.0027 | ACC: 0.5172
# Confusion matrix:
# [[  1 153]
#  [  1 164]]
#
#
# ========================================
# Training model for: ADBE
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ADBE] Test AUC: 0.4966 | F1: 0.6845 | MCC: 0.0000 | ACC: 0.5204
# Confusion matrix:
# [[  0 153]
#  [  0 166]]
#
#
# ========================================
# Training model for: AEO
# ========================================
# Test class distribution: 0s=42.95%, 1s=57.05%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [AEO] Test AUC: 0.5184 | F1: 0.7152 | MCC: 0.0369 | ACC: 0.5705
# Confusion matrix:
# [[ 10 127]
#  [ 10 172]]
#
#
# ========================================
# Training model for: AIG
# ========================================
# Test class distribution: 0s=44.51%, 1s=55.49%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [AIG] Test AUC: 0.4799 | F1: 0.7137 | MCC: 0.0000 | ACC: 0.5549
# Confusion matrix:
# [[  0 142]
#  [  0 177]]
#
#
# ========================================
# Training model for: ALK
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ALK] Test AUC: 0.5044 | F1: 0.5962 | MCC: 0.0641 | ACC: 0.5329
# Confusion matrix:
# [[ 60  97]
#  [ 52 110]]
#
#
# ========================================
# Training model for: AMGN
# ========================================
# Test class distribution: 0s=54.86%, 1s=45.14%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [AMGN] Test AUC: 0.4303 | F1: 0.5818 | MCC: -0.1368 | ACC: 0.4232
# Confusion matrix:
# [[  7 168]
#  [ 16 128]]
#
#
# ========================================
# Training model for: AMT
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [AMT] Test AUC: 0.4818 | F1: 0.6483 | MCC: 0.0000 | ACC: 0.4796
# Confusion matrix:
# [[  0 166]
#  [  0 153]]
#
#
# ========================================
# Training model for: BABA
# ========================================
# Test class distribution: 0s=54.55%, 1s=45.45%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BABA] Test AUC: 0.5047 | F1: 0.0135 | MCC: -0.0237 | ACC: 0.5423
# Confusion matrix:
# [[172   2]
#  [144   1]]
#
#
# ========================================
# Training model for: BHP
# ========================================
# Test class distribution: 0s=49.53%, 1s=50.47%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BHP] Test AUC: 0.4969 | F1: 0.6708 | MCC: 0.0000 | ACC: 0.5047
# Confusion matrix:
# [[  0 158]
#  [  0 161]]
#
#
# ========================================
# Training model for: BIDU
# ========================================
# Test class distribution: 0s=55.49%, 1s=44.51%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BIDU] Test AUC: 0.4947 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.5549
# Confusion matrix:
# [[177   0]
#  [142   0]]
#
#
# ========================================
# Training model for: BIIB
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [BIIB] Test AUC: 0.5324 | F1: 0.6154 | MCC: 0.0076 | ACC: 0.4828
# Confusion matrix:
# [[ 22 146]
#  [ 19 132]]
#
#
# ========================================
# Training model for: BSX
# ========================================
# Test class distribution: 0s=46.39%, 1s=53.61%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BSX] Test AUC: 0.5187 | F1: 0.6605 | MCC: 0.0419 | ACC: 0.5392
# Confusion matrix:
# [[ 29 119]
#  [ 28 143]]
#
#
# ========================================
# Training model for: BX
# ========================================
# Test class distribution: 0s=47.34%, 1s=52.66%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BX] Test AUC: 0.5287 | F1: 0.6437 | MCC: 0.0743 | ACC: 0.5455
# Confusion matrix:
# [[ 43 108]
#  [ 37 131]]
#
#
# ========================================
# Training model for: CAT
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [CAT] Test AUC: 0.5065 | F1: 0.6064 | MCC: -0.0215 | ACC: 0.4953
# Confusion matrix:
# [[ 34 123]
#  [ 38 124]]
#
#
# ========================================
# Training model for: CI
# ========================================
# Test class distribution: 0s=46.08%, 1s=53.92%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CI] Test AUC: 0.5163 | F1: 0.7006 | MCC: 0.0000 | ACC: 0.5392
# Confusion matrix:
# [[  0 147]
#  [  0 172]]
#
#
# ========================================
# Training model for: CMCSA
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CMCSA] Test AUC: 0.4917 | F1: 0.6638 | MCC: -0.0061 | ACC: 0.5110
# Confusion matrix:
# [[  9 146]
#  [ 10 154]]
#
#
# ========================================
# Training model for: CMG
# ========================================
# Test class distribution: 0s=43.89%, 1s=56.11%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [CMG] Test AUC: 0.4451 | F1: 0.5926 | MCC: -0.0947 | ACC: 0.4828
# Confusion matrix:
# [[ 34 106]
#  [ 59 120]]
#
#
# ========================================
# Training model for: COP
# ========================================
# Test class distribution: 0s=50.47%, 1s=49.53%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [COP] Test AUC: 0.4679 | F1: 0.6625 | MCC: 0.0000 | ACC: 0.4953
# Confusion matrix:
# [[  0 161]
#  [  0 158]]
#
#
# ========================================
# Training model for: COST
# ========================================
# Test class distribution: 0s=45.77%, 1s=54.23%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [COST] Test AUC: 0.5284 | F1: 0.7047 | MCC: 0.0610 | ACC: 0.5455
# Confusion matrix:
# [[  1 145]
#  [  0 173]]
#
#
# ========================================
# Training model for: CRM
# ========================================
# Test class distribution: 0s=47.02%, 1s=52.98%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [CRM] Test AUC: 0.5005 | F1: 0.5762 | MCC: 0.0293 | ACC: 0.5204
# Confusion matrix:
# [[ 62  88]
#  [ 65 104]]
#
#
# ========================================
# Training model for: CSX
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CSX] Test AUC: 0.4856 | F1: 0.6378 | MCC: 0.0583 | ACC: 0.5016
# Confusion matrix:
# [[ 20 146]
#  [ 13 140]]
#
#
# ========================================
# Training model for: D
# ========================================
# Test class distribution: 0s=49.53%, 1s=50.47%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [D] Test AUC: 0.5428 | F1: 0.6575 | MCC: 0.0849 | ACC: 0.5329
# Confusion matrix:
# [[ 27 131]
#  [ 18 143]]
#
#
# ========================================
# Training model for: DB
# ========================================
# Test class distribution: 0s=42.95%, 1s=57.05%
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DB] Test AUC: 0.5542 | F1: 0.5266 | MCC: 0.0747 | ACC: 0.5266
# Confusion matrix:
# [[84 53]
#  [98 84]]
#
#
# ========================================
# Training model for: DE
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DE] Test AUC: 0.5416 | F1: 0.6845 | MCC: 0.0000 | ACC: 0.5204
# Confusion matrix:
# [[  0 153]
#  [  0 166]]
#
#
# ========================================
# Training model for: DFS
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DFS] Test AUC: 0.5075 | F1: 0.6210 | MCC: -0.0877 | ACC: 0.4796
# Confusion matrix:
# [[ 17 138]
#  [ 28 136]]
#
#
# ========================================
# Training model for: DHI
# ========================================
# Test class distribution: 0s=45.45%, 1s=54.55%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DHI] Test AUC: 0.5412 | F1: 0.6573 | MCC: 0.0393 | ACC: 0.5423
# Confusion matrix:
# [[ 33 112]
#  [ 34 140]]
#
#
# ========================================
# Training model for: DHR
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DHR] Test AUC: 0.5206 | F1: 0.6636 | MCC: 0.0777 | ACC: 0.5423
# Confusion matrix:
# [[ 29 124]
#  [ 22 144]]
#
#
# ========================================
# Training model for: DISH
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DISH] Test AUC: 0.4861 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.5298
# Confusion matrix:
# [[169   0]
#  [150   0]]
#
#
# ========================================
# Training model for: DPZ
# ========================================
# Test class distribution: 0s=50.16%, 1s=49.84%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DPZ] Test AUC: 0.4582 | F1: 0.6653 | MCC: 0.0000 | ACC: 0.4984
# Confusion matrix:
# [[  0 160]
#  [  0 159]]
#
#
# ========================================
# Training model for: DUK
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DUK] Test AUC: 0.4726 | F1: 0.6169 | MCC: 0.0308 | ACC: 0.5172
# Confusion matrix:
# [[ 41 116]
#  [ 38 124]]
#
#
# ========================================
# Training model for: EA
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [EA] Test AUC: 0.5317 | F1: 0.6819 | MCC: 0.0046 | ACC: 0.5204
# Confusion matrix:
# [[  2 151]
#  [  2 164]]
#
#
# ========================================
# Training model for: EBAY
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [EBAY] Test AUC: 0.5339 | F1: 0.6540 | MCC: 0.0000 | ACC: 0.4859
# Confusion matrix:
# [[  0 164]
#  [  0 155]]
#
#
# ========================================
# Training model for: ENB
# ========================================
# Test class distribution: 0s=51.10%, 1s=48.90%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [ENB] Test AUC: 0.5576 | F1: 0.6568 | MCC: 0.0000 | ACC: 0.4890
# Confusion matrix:
# [[  0 163]
#  [  0 156]]
#
#
# ========================================
# Training model for: EOG
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [EOG] Test AUC: 0.4503 | F1: 0.6540 | MCC: 0.0000 | ACC: 0.4859
# Confusion matrix:
# [[  0 164]
#  [  0 155]]
#
#
# ========================================
# Training model for: FDX
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [FDX] Test AUC: 0.5066 | F1: 0.5913 | MCC: 0.0185 | ACC: 0.5016
# Confusion matrix:
# [[ 45 119]
#  [ 40 115]]
#
#
# ========================================
# Training model for: FSLR
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [FSLR] Test AUC: 0.5615 | F1: 0.6496 | MCC: 0.0518 | ACC: 0.4859
# Confusion matrix:
# [[  3 163]
#  [  1 152]]
#
#
# ========================================
# Training model for: GE
# ========================================
# Test class distribution: 0s=44.20%, 1s=55.80%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [GE] Test AUC: 0.4618 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.4420
# Confusion matrix:
# [[141   0]
#  [178   0]]
#
#
# ========================================
# Training model for: GILD
# ========================================
# Test class distribution: 0s=47.34%, 1s=52.66%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [GILD] Test AUC: 0.5631 | F1: 0.5180 | MCC: 0.0869 | ACC: 0.5392
# Confusion matrix:
# [[93 58]
#  [89 79]]
#
#
# ========================================
# Training model for: GME
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [GME] Test AUC: 0.5296 | F1: 0.5771 | MCC: 0.0903 | ACC: 0.5361
# Confusion matrix:
# [[ 70  99]
#  [ 49 101]]
#
#
# ========================================
# Training model for: GS
# ========================================
# Test class distribution: 0s=49.53%, 1s=50.47%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [GS] Test AUC: 0.5398 | F1: 0.4502 | MCC: 0.0723 | ACC: 0.5329
# Confusion matrix:
# [[109  49]
#  [100  61]]
#
#
# ========================================
# Training model for: GSK
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [GSK] Test AUC: 0.5170 | F1: 0.6162 | MCC: 0.0384 | ACC: 0.5235
# Confusion matrix:
# [[ 45 110]
#  [ 42 122]]
#
#
# ========================================
# Training model for: HAL
# ========================================
# Test class distribution: 0s=47.65%, 1s=52.35%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [HAL] Test AUC: 0.4428 | F1: 0.3516 | MCC: -0.0998 | ACC: 0.4451
# Confusion matrix:
# [[ 94  58]
#  [119  48]]
#
#
# ========================================
# Training model for: HPQ
# ========================================
# Test class distribution: 0s=50.47%, 1s=49.53%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [HPQ] Test AUC: 0.5159 | F1: 0.6625 | MCC: 0.0000 | ACC: 0.4953
# Confusion matrix:
# [[  0 161]
#  [  0 158]]
#
#
# ========================================
# Training model for: HUM
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [HUM] Test AUC: 0.5073 | F1: 0.6667 | MCC: -0.0046 | ACC: 0.5141
# Confusion matrix:
# [[  9 145]
#  [ 10 155]]
#
#
# ========================================
# Training model for: KMB
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [KMB] Test AUC: 0.5057 | F1: 0.6764 | MCC: 0.0807 | ACC: 0.5141
# Confusion matrix:
# [[  2 155]
#  [  0 162]]
#
#
# ========================================
# Training model for: KO
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [KO] Test AUC: 0.5301 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: KSS
# ========================================
# Test class distribution: 0s=53.29%, 1s=46.71%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [KSS] Test AUC: 0.5287 | F1: 0.5785 | MCC: 0.0674 | ACC: 0.5204
# Confusion matrix:
# [[ 61 109]
#  [ 44 105]]
#
#
# ========================================
# Training model for: MRK
# ========================================
# Test class distribution: 0s=44.83%, 1s=55.17%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [MRK] Test AUC: 0.5023 | F1: 0.6743 | MCC: 0.0577 | ACC: 0.5549
# Confusion matrix:
# [[ 30 113]
#  [ 29 147]]
#
#
# ========================================
# Training model for: MS
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [MS] Test AUC: 0.4911 | F1: 0.6425 | MCC: 0.0728 | ACC: 0.5047
# Confusion matrix:
# [[ 19 147]
#  [ 11 142]]
#
#
# ========================================
# Training model for: MU
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [MU] Test AUC: 0.5262 | F1: 0.6426 | MCC: 0.0000 | ACC: 0.4734
# Confusion matrix:
# [[  0 168]
#  [  0 151]]
#
#
# ========================================
# Training model for: NEE
# ========================================
# Test class distribution: 0s=51.10%, 1s=48.90%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NEE] Test AUC: 0.4958 | F1: 0.6568 | MCC: 0.0000 | ACC: 0.4890
# Confusion matrix:
# [[  0 163]
#  [  0 156]]
#
#
# ========================================
# Training model for: NEM
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NEM] Test AUC: 0.5396 | F1: 0.6368 | MCC: -0.0595 | ACC: 0.4671
# Confusion matrix:
# [[  0 169]
#  [  1 149]]
#
#
# ========================================
# Training model for: NKE
# ========================================
# Test class distribution: 0s=51.10%, 1s=48.90%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NKE] Test AUC: 0.5015 | F1: 0.6568 | MCC: 0.0303 | ACC: 0.4922
# Confusion matrix:
# [[  2 161]
#  [  1 155]]
#
#
# ========================================
# Training model for: NOC
# ========================================
# Test class distribution: 0s=47.02%, 1s=52.98%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NOC] Test AUC: 0.5079 | F1: 0.6926 | MCC: 0.0000 | ACC: 0.5298
# Confusion matrix:
# [[  0 150]
#  [  0 169]]
#
#
# ========================================
# Training model for: NVS
# ========================================
# Test class distribution: 0s=47.65%, 1s=52.35%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NVS] Test AUC: 0.4892 | F1: 0.6524 | MCC: -0.1173 | ACC: 0.4922
# Confusion matrix:
# [[  5 147]
#  [ 15 152]]
#
#
# ========================================
# Training model for: ORCL
# ========================================
# Test class distribution: 0s=43.89%, 1s=56.11%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ORCL] Test AUC: 0.5632 | F1: 0.6520 | MCC: 0.0632 | ACC: 0.5549
# Confusion matrix:
# [[ 44  96]
#  [ 46 133]]
#
#
# ========================================
# Training model for: OXY
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [OXY] Test AUC: 0.5463 | F1: 0.5722 | MCC: 0.0018 | ACC: 0.4890
# Confusion matrix:
# [[ 47 121]
#  [ 42 109]]
#
#
# ========================================
# Training model for: PANW
# ========================================
# Test class distribution: 0s=46.71%, 1s=53.29%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PANW] Test AUC: 0.4638 | F1: 0.5076 | MCC: -0.0084 | ACC: 0.4953
# Confusion matrix:
# [[75 74]
#  [87 83]]
#
#
# ========================================
# Training model for: PBR
# ========================================
# Test class distribution: 0s=47.65%, 1s=52.35%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PBR] Test AUC: 0.4595 | F1: 0.6565 | MCC: -0.0548 | ACC: 0.5047
# Confusion matrix:
# [[ 10 142]
#  [ 16 151]]
#
#
# ========================================
# Training model for: PEP
# ========================================
# Test class distribution: 0s=49.84%, 1s=50.16%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PEP] Test AUC: 0.5343 | F1: 0.6681 | MCC: 0.0000 | ACC: 0.5016
# Confusion matrix:
# [[  0 159]
#  [  0 160]]
#
#
# ========================================
# Training model for: PXD
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PXD] Test AUC: 0.5273 | F1: 0.5913 | MCC: -0.0039 | ACC: 0.5016
# Confusion matrix:
# [[ 45 112]
#  [ 47 115]]
#
#
# ========================================
# Training model for: QCOM
# ========================================
# Test class distribution: 0s=50.78%, 1s=49.22%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [QCOM] Test AUC: 0.5257 | F1: 0.5761 | MCC: 0.0285 | ACC: 0.5110
# Confusion matrix:
# [[ 57 105]
#  [ 51 106]]
#
#
# ========================================
# Training model for: SPWR
# ========================================
# Test class distribution: 0s=55.80%, 1s=44.20%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [SPWR] Test AUC: 0.5228 | F1: 0.4599 | MCC: 0.0539 | ACC: 0.5361
# Confusion matrix:
# [[108  70]
#  [ 78  63]]
#
#
# ========================================
# Training model for: T
# ========================================
# Test class distribution: 0s=49.84%, 1s=50.16%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [T] Test AUC: 0.5298 | F1: 0.6638 | MCC: 0.0004 | ACC: 0.5016
# Confusion matrix:
# [[  3 156]
#  [  3 157]]
#
#
# ========================================
# Training model for: TJX
# ========================================
# Test class distribution: 0s=48.90%, 1s=51.10%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TJX] Test AUC: 0.5180 | F1: 0.6316 | MCC: 0.0267 | ACC: 0.5172
# Confusion matrix:
# [[ 33 123]
#  [ 31 132]]
#
#
# ========================================
# Training model for: TM
# ========================================
# Test class distribution: 0s=46.39%, 1s=53.61%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TM] Test AUC: 0.4582 | F1: 0.4724 | MCC: -0.0766 | ACC: 0.4608
# Confusion matrix:
# [[70 78]
#  [94 77]]
#
#
# ========================================
# Training model for: TMUS
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TMUS] Test AUC: 0.5148 | F1: 0.0457 | MCC: -0.0259 | ACC: 0.4765
# Confusion matrix:
# [[148   5]
#  [162   4]]
#
#
# ========================================
# Training model for: TRV
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TRV] Test AUC: 0.5100 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: TSM
# ========================================
# Test class distribution: 0s=54.23%, 1s=45.77%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TSM] Test AUC: 0.5191 | F1: 0.6263 | MCC: -0.0067 | ACC: 0.4577
# Confusion matrix:
# [[  1 172]
#  [  1 145]]
#
#
# ========================================
# Training model for: TSN
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TSN] Test AUC: 0.5116 | F1: 0.6298 | MCC: 0.0999 | ACC: 0.5172
# Confusion matrix:
# [[ 34 135]
#  [ 19 131]]
#
#
# ========================================
# Training model for: TXN
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TXN] Test AUC: 0.4520 | F1: 0.6540 | MCC: 0.0000 | ACC: 0.4859
# Confusion matrix:
# [[  0 164]
#  [  0 155]]
#
#
# ========================================
# Training model for: USB
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [USB] Test AUC: 0.4716 | F1: 0.6426 | MCC: 0.0000 | ACC: 0.4734
# Confusion matrix:
# [[  0 168]
#  [  0 151]]
#
#
# ========================================
# Training model for: V
# ========================================
# Test class distribution: 0s=47.34%, 1s=52.66%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [V] Test AUC: 0.4878 | F1: 0.6899 | MCC: 0.0000 | ACC: 0.5266
# Confusion matrix:
# [[  0 151]
#  [  0 168]]
#
#
# ========================================
# Training model for: VRTX
# ========================================
# Test class distribution: 0s=44.20%, 1s=55.80%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [VRTX] Test AUC: 0.5007 | F1: 0.6603 | MCC: 0.0505 | ACC: 0.5517
# Confusion matrix:
# [[ 37 104]
#  [ 39 139]]
#
#
# ========================================
# Training model for: WBA
# ========================================
# Test class distribution: 0s=55.49%, 1s=44.51%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [WBA] Test AUC: 0.5019 | F1: 0.4573 | MCC: -0.0027 | ACC: 0.5016
# Confusion matrix:
# [[93 84]
#  [75 67]]
#
#
# ========================================
# Training model for: WDC
# ========================================
# Test class distribution: 0s=50.16%, 1s=49.84%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [WDC] Test AUC: 0.4559 | F1: 0.5671 | MCC: -0.0805 | ACC: 0.4639
# Confusion matrix:
# [[ 36 124]
#  [ 47 112]]
#
#
# ========================================
# Training model for: WFC
# ========================================
# Test class distribution: 0s=48.43%, 1s=51.57%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [WFC] Test AUC: 0.5197 | F1: 0.6329 | MCC: 0.0318 | ACC: 0.5220
# Confusion matrix:
# [[ 35 119]
#  [ 33 131]]
#
#
# === Summary of all stocks ===
#    Symbol   Val_AUC    Val_F1   Val_MCC  Test_AUC   Test_F1  Test_MCC  \
# 0     AAL  0.507696  0.479233 -0.029552  0.567414  0.603175  0.050977
# 57   ORCL  0.492782  0.620690  0.055524  0.563168  0.651961  0.063187
# 39   GILD  0.510075  0.496774  0.012464  0.563111  0.518033  0.086879
# 37   FSLR  0.515663  0.653763 -0.057073  0.561462  0.649573  0.051794
# 34    ENB  0.566151  0.707566  0.000000  0.557574  0.656842  0.000000
# ..    ...       ...       ...       ...       ...       ...       ...
# 72    TXN  0.503813  0.686071  0.000000  0.452026  0.654008  0.000000
# 35    EOG  0.529303  0.669474  0.000000  0.450275  0.654008  0.000000
# 18    CMG  0.540840  0.639798  0.114910  0.445132  0.592593 -0.094727
# 43    HAL  0.494923  0.364964 -0.092156  0.442759  0.351648 -0.099833
# 7    AMGN  0.462051  0.659292 -0.018819  0.430278  0.581818 -0.136813
#
#     Test_ACC    Test_0%    Test_1%
# 0   0.529781  48.275862  51.724138
# 57  0.554859  43.887147  56.112853
# 39  0.539185  47.335423  52.664577
# 37  0.485893  52.037618  47.962382
# 34  0.489028  51.097179  48.902821
# ..       ...        ...        ...
# 72  0.485893  51.410658  48.589342
# 35  0.485893  51.410658  48.589342
# 18  0.482759  43.887147  56.112853
# 43  0.445141  47.648903  52.351097
# 7   0.423197  54.858934  45.141066
#
# [79 rows x 10 columns]

# %%
print(results_df['Test_AUC'].mean())
print(results_df['Test_ACC'].mean())
print(results_df['Test_MCC'].mean())
# Out:
# 0.5075233283548944
# 0.5090084525446854
# 0.011235580624254676

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, matthews_corrcoef, confusion_matrix, roc_auc_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# === PARAMETERS ===
window_size = 10
feature_cols = ['open_logret', 'high_logret', 'low_logret', 'close_logret', 'volume_logret']
target = 'target_binary'
l2_value = 1e-4
batch_size = 8
epochs = 50
learning_rate = 0.001

# Results dataframe
results = []

# === LOOP THROUGH EACH STOCK ===
for symbol in df['Stock_symbol'].unique():
    print(f"\n{'='*40}\nTraining model for: {symbol}\n{'='*40}")

    # Subset dataframe
    df_symbol = df[df['Stock_symbol'] == symbol].copy()
    price_cols = ['open', 'high', 'low', 'close', 'volume']
    for col in price_cols:
      df_symbol[f'{col}_logret'] = np.log(df_symbol[col]) - np.log(df_symbol[col].shift(1))
    df_symbol.dropna(inplace=True)

    # Define time splits
    train = df_symbol.loc['2014-01-01':'2021-03-29']
    val = df_symbol.loc['2021-03-30':'2022-07-28']
    test = df_symbol.loc['2022-07-29':'2023-12-01']

    # Skip if insufficient data
    if len(train) < window_size * 2 or len(test) < window_size:
        print(f"Not enough data for {symbol}, skipping.")
        continue

    # Create sequences (your sequences() function should return numpy arrays)
    X_train, y_train = sequences(train, window_size=window_size, feature_cols=feature_cols, target=target)
    X_val, y_val = sequences(val, window_size=window_size, feature_cols=feature_cols, target=target)
    X_test, y_test = sequences(test, window_size=window_size, feature_cols=feature_cols, target=target)

    X_train = np.array(X_train); y_train = np.array(y_train)
    X_val = np.array(X_val); y_val = np.array(y_val)
    X_test = np.array(X_test); y_test = np.array(y_test)

    # Replace NaNs and normalize
    for X in [X_train, X_val, X_test]:
        np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0, copy=False)

    mean = np.mean(X_train, axis=(0,1))
    std = np.std(X_train, axis=(0,1))
    std[std == 0] = 1e-8

    # X_train_norm = (X_train - mean) / std
    # X_val_norm = (X_val - mean) / std
    # X_test_norm = (X_test - mean) / std

    # Print class distribution for test
    unique, counts = np.unique(y_test, return_counts=True)
    dist = dict(zip(unique, counts))
    total = counts.sum()
    pct_0 = 100 * dist.get(0, 0) / total
    pct_1 = 100 * dist.get(1, 0) / total
    print(f"Test class distribution: 0s={pct_0:.2f}%, 1s={pct_1:.2f}%")

    # === Model ===
    model = Sequential([
        Input(shape=(window_size, len(feature_cols))),
        Conv1D(filters=16, kernel_size=3, strides=1, activation='relu', padding='same'),
        BatchNormalization(),
        Conv1D(filters=8, kernel_size=3, strides=1, activation='relu', padding='same'),
        BatchNormalization(),
        LSTM(16),
        Dropout(0.1),
        Dense(16, activation='relu'),
        Dropout(0.2),
        Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_value))
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC', 'accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # === Train ===
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=0
    )

    # === Evaluation ===
    y_val_pred_prob = model.predict(X_val)
    y_val_pred = (y_val_pred_prob > 0.5).astype(int)

    y_test_pred_prob = model.predict(X_test)
    y_test_pred = (y_test_pred_prob > 0.5).astype(int)

    # Validation metrics
    val_auc = roc_auc_score(y_val, y_val_pred_prob)
    val_f1 = f1_score(y_val, y_val_pred)
    val_mcc = matthews_corrcoef(y_val, y_val_pred)

    # Test metrics
    test_auc = roc_auc_score(y_test, y_test_pred_prob)
    test_f1 = f1_score(y_test, y_test_pred)
    test_mcc = matthews_corrcoef(y_test, y_test_pred)
    test_acc = np.mean(y_test_pred.flatten() == y_test.flatten())
    test_cm = confusion_matrix(y_test, y_test_pred)

    print(f"[{symbol}] Test AUC: {test_auc:.4f} | F1: {test_f1:.4f} | MCC: {test_mcc:.4f} | ACC: {test_acc:.4f}")
    print(f"Confusion matrix:\n{test_cm}\n")

    # Save results
    results.append({
        'Symbol': symbol,
        'Val_AUC': val_auc,
        'Val_F1': val_f1,
        'Val_MCC': val_mcc,
        'Test_AUC': test_auc,
        'Test_F1': test_f1,
        'Test_MCC': test_mcc,
        'Test_ACC': test_acc,
        'Test_0%': pct_0,
        'Test_1%': pct_1
    })

# === SAVE ALL RESULTS ===
results_df = pd.DataFrame(results)
results_df.to_csv('model_results_per_stock_log_window10.csv', index=False)
print("\n=== Summary of all stocks ===")
print(results_df.sort_values('Test_AUC', ascending=False))
# Out:
# ========================================
# Training model for: AAL
# ========================================
# Test class distribution: 0s=48.33%, 1s=51.67%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [AAL] Test AUC: 0.5849 | F1: 0.6375 | MCC: 0.1397 | ACC: 0.5714
# Confusion matrix:
# [[ 64  95]
#  [ 46 124]]
#
#
# ========================================
# Training model for: ABBV
# ========================================
# Test class distribution: 0s=48.94%, 1s=51.06%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ABBV] Test AUC: 0.5546 | F1: 0.6459 | MCC: 0.0260 | ACC: 0.5167
# Confusion matrix:
# [[ 25 136]
#  [ 23 145]]
#
#
# ========================================
# Training model for: ACN
# ========================================
# Test class distribution: 0s=48.94%, 1s=51.06%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ACN] Test AUC: 0.4786 | F1: 0.6583 | MCC: -0.0362 | ACC: 0.5015
# Confusion matrix:
# [[  7 154]
#  [ 10 158]]
#
#
# ========================================
# Training model for: ADBE
# ========================================
# Test class distribution: 0s=48.94%, 1s=51.06%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ADBE] Test AUC: 0.4346 | F1: 0.6761 | MCC: 0.0000 | ACC: 0.5106
# Confusion matrix:
# [[  0 161]
#  [  0 168]]
#
#
# ========================================
# Training model for: AEO
# ========================================
# Test class distribution: 0s=43.16%, 1s=56.84%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [AEO] Test AUC: 0.4719 | F1: 0.7262 | MCC: 0.0634 | ACC: 0.5714
# Confusion matrix:
# [[  1 141]
#  [  0 187]]
#
#
# ========================================
# Training model for: AIG
# ========================================
# Test class distribution: 0s=44.68%, 1s=55.32%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [AIG] Test AUC: 0.5129 | F1: 0.5641 | MCC: 0.0674 | ACC: 0.5350
# Confusion matrix:
# [[77 70]
#  [83 99]]
#
#
# ========================================
# Training model for: ALK
# ========================================
# Test class distribution: 0s=49.24%, 1s=50.76%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ALK] Test AUC: 0.5360 | F1: 0.6653 | MCC: -0.0945 | ACC: 0.4985
# Confusion matrix:
# [[  0 162]
#  [  3 164]]
#
#
# ========================================
# Training model for: AMGN
# ========================================
# Test class distribution: 0s=54.71%, 1s=45.29%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [AMGN] Test AUC: 0.4945 | F1: 0.5707 | MCC: -0.0373 | ACC: 0.4559
# Confusion matrix:
# [[ 31 149]
#  [ 30 119]]
#
#
# ========================================
# Training model for: AMT
# ========================================
# Test class distribution: 0s=52.89%, 1s=47.11%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [AMT] Test AUC: 0.5043 | F1: 0.6405 | MCC: 0.0000 | ACC: 0.4711
# Confusion matrix:
# [[  0 174]
#  [  0 155]]
#
#
# ========================================
# Training model for: BABA
# ========================================
# Test class distribution: 0s=54.71%, 1s=45.29%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BABA] Test AUC: 0.5058 | F1: 0.3883 | MCC: -0.0398 | ACC: 0.4924
# Confusion matrix:
# [[109  71]
#  [ 96  53]]
#
#
# ========================================
# Training model for: BHP
# ========================================
# Test class distribution: 0s=49.54%, 1s=50.46%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BHP] Test AUC: 0.5400 | F1: 0.6051 | MCC: -0.0578 | ACC: 0.4802
# Confusion matrix:
# [[ 27 136]
#  [ 35 131]]
#
#
# ========================================
# Training model for: BIDU
# ========================================
# Test class distribution: 0s=55.32%, 1s=44.68%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BIDU] Test AUC: 0.4399 | F1: 0.3932 | MCC: -0.0999 | ACC: 0.4559
# Confusion matrix:
# [[92 90]
#  [89 58]]
#
#
# ========================================
# Training model for: BIIB
# ========================================
# Test class distribution: 0s=53.50%, 1s=46.50%
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BIIB] Test AUC: 0.4626 | F1: 0.4486 | MCC: -0.0747 | ACC: 0.4620
# Confusion matrix:
# [[80 96]
#  [81 72]]
#
#
# ========================================
# Training model for: BSX
# ========================================
# Test class distribution: 0s=46.50%, 1s=53.50%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BSX] Test AUC: 0.4853 | F1: 0.6970 | MCC: 0.0000 | ACC: 0.5350
# Confusion matrix:
# [[  0 153]
#  [  0 176]]
#
#
# ========================================
# Training model for: BX
# ========================================
# Test class distribution: 0s=47.72%, 1s=52.28%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BX] Test AUC: 0.4953 | F1: 0.6751 | MCC: 0.0362 | ACC: 0.5289
# Confusion matrix:
# [[ 13 144]
#  [ 11 161]]
#
#
# ========================================
# Training model for: CAT
# ========================================
# Test class distribution: 0s=49.54%, 1s=50.46%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [CAT] Test AUC: 0.5374 | F1: 0.6481 | MCC: -0.0079 | ACC: 0.5015
# Confusion matrix:
# [[ 14 149]
#  [ 15 151]]
#
#
# ========================================
# Training model for: CI
# ========================================
# Test class distribution: 0s=46.50%, 1s=53.50%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [CI] Test AUC: 0.4990 | F1: 0.6970 | MCC: 0.0000 | ACC: 0.5350
# Confusion matrix:
# [[  0 153]
#  [  0 176]]
#
#
# ========================================
# Training model for: CMCSA
# ========================================
# Test class distribution: 0s=49.24%, 1s=50.76%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [CMCSA] Test AUC: 0.4559 | F1: 0.6107 | MCC: -0.0301 | ACC: 0.4924
# Confusion matrix:
# [[ 31 131]
#  [ 36 131]]
#
#
# ========================================
# Training model for: CMG
# ========================================
# Test class distribution: 0s=44.07%, 1s=55.93%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [CMG] Test AUC: 0.5024 | F1: 0.4706 | MCC: -0.0215 | ACC: 0.4802
# Confusion matrix:
# [[ 82  63]
#  [108  76]]
#
#
# ========================================
# Training model for: COP
# ========================================
# Test class distribution: 0s=49.54%, 1s=50.46%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [COP] Test AUC: 0.4921 | F1: 0.3838 | MCC: -0.0128 | ACC: 0.4924
# Confusion matrix:
# [[110  53]
#  [114  52]]
#
#
# ========================================
# Training model for: COST
# ========================================
# Test class distribution: 0s=45.59%, 1s=54.41%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [COST] Test AUC: 0.4842 | F1: 0.6530 | MCC: 0.0311 | ACC: 0.5380
# Confusion matrix:
# [[ 34 116]
#  [ 36 143]]
#
#
# ========================================
# Training model for: CRM
# ========================================
# Test class distribution: 0s=48.02%, 1s=51.98%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CRM] Test AUC: 0.4988 | F1: 0.6611 | MCC: -0.0231 | ACC: 0.5106
# Confusion matrix:
# [[ 11 147]
#  [ 14 157]]
#
#
# ========================================
# Training model for: CSX
# ========================================
# Test class distribution: 0s=52.28%, 1s=47.72%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CSX] Test AUC: 0.5147 | F1: 0.6461 | MCC: 0.0000 | ACC: 0.4772
# Confusion matrix:
# [[  0 172]
#  [  0 157]]
#
#
# ========================================
# Training model for: D
# ========================================
# Test class distribution: 0s=49.54%, 1s=50.46%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [D] Test AUC: 0.5339 | F1: 0.6294 | MCC: 0.0349 | ACC: 0.5167
# Confusion matrix:
# [[ 35 128]
#  [ 31 135]]
#
#
# ========================================
# Training model for: DB
# ========================================
# Test class distribution: 0s=44.07%, 1s=55.93%
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DB] Test AUC: 0.4969 | F1: 0.4387 | MCC: -0.0311 | ACC: 0.4711
# Confusion matrix:
# [[ 87  58]
#  [116  68]]
#
#
# ========================================
# Training model for: DE
# ========================================
# Test class distribution: 0s=47.72%, 1s=52.28%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DE] Test AUC: 0.5382 | F1: 0.6010 | MCC: 0.0526 | ACC: 0.5319
# Confusion matrix:
# [[ 59  98]
#  [ 56 116]]
#
#
# ========================================
# Training model for: DFS
# ========================================
# Test class distribution: 0s=49.24%, 1s=50.76%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DFS] Test AUC: 0.4537 | F1: 0.6288 | MCC: -0.0706 | ACC: 0.4833
# Confusion matrix:
# [[ 15 147]
#  [ 23 144]]
#
#
# ========================================
# Training model for: DHI
# ========================================
# Test class distribution: 0s=45.90%, 1s=54.10%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DHI] Test AUC: 0.5562 | F1: 0.6453 | MCC: 0.1011 | ACC: 0.5623
# Confusion matrix:
# [[ 54  97]
#  [ 47 131]]
#
#
# ========================================
# Training model for: DHR
# ========================================
# Test class distribution: 0s=48.63%, 1s=51.37%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DHR] Test AUC: 0.4900 | F1: 0.6337 | MCC: -0.0128 | ACC: 0.5046
# Confusion matrix:
# [[ 25 135]
#  [ 28 141]]
#
#
# ========================================
# Training model for: DISH
# ========================================
# Test class distribution: 0s=53.19%, 1s=46.81%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DISH] Test AUC: 0.5619 | F1: 0.5000 | MCC: 0.1265 | ACC: 0.5684
# Confusion matrix:
# [[116  59]
#  [ 83  71]]
#
#
# ========================================
# Training model for: DPZ
# ========================================
# Test class distribution: 0s=50.15%, 1s=49.85%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DPZ] Test AUC: 0.4852 | F1: 0.6582 | MCC: 0.0383 | ACC: 0.5076
# Confusion matrix:
# [[ 11 154]
#  [  8 156]]
#
#
# ========================================
# Training model for: DUK
# ========================================
# Test class distribution: 0s=49.54%, 1s=50.46%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DUK] Test AUC: 0.4538 | F1: 0.6707 | MCC: 0.0000 | ACC: 0.5046
# Confusion matrix:
# [[  0 163]
#  [  0 166]]
#
#
# ========================================
# Training model for: EA
# ========================================
# Test class distribution: 0s=48.33%, 1s=51.67%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [EA] Test AUC: 0.5359 | F1: 0.6072 | MCC: -0.0083 | ACC: 0.5046
# Confusion matrix:
# [[ 40 119]
#  [ 44 126]]
#
#
# ========================================
# Training model for: EBAY
# ========================================
# Test class distribution: 0s=51.67%, 1s=48.33%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [EBAY] Test AUC: 0.4591 | F1: 0.6516 | MCC: 0.0000 | ACC: 0.4833
# Confusion matrix:
# [[  0 170]
#  [  0 159]]
#
#
# ========================================
# Training model for: ENB
# ========================================
# Test class distribution: 0s=51.06%, 1s=48.94%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ENB] Test AUC: 0.5449 | F1: 0.6223 | MCC: 0.0562 | ACC: 0.5167
# Confusion matrix:
# [[ 39 129]
#  [ 30 131]]
#
#
# ========================================
# Training model for: EOG
# ========================================
# Test class distribution: 0s=50.76%, 1s=49.24%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [EOG] Test AUC: 0.5081 | F1: 0.6456 | MCC: -0.0173 | ACC: 0.4894
# Confusion matrix:
# [[  8 159]
#  [  9 153]]
#
#
# ========================================
# Training model for: FDX
# ========================================
# Test class distribution: 0s=51.06%, 1s=48.94%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [FDX] Test AUC: 0.5239 | F1: 0.6571 | MCC: 0.0000 | ACC: 0.4894
# Confusion matrix:
# [[  0 168]
#  [  0 161]]
#
#
# ========================================
# Training model for: FSLR
# ========================================
# Test class distribution: 0s=51.98%, 1s=48.02%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [FSLR] Test AUC: 0.4620 | F1: 0.6511 | MCC: 0.0870 | ACC: 0.5015
# Confusion matrix:
# [[ 12 159]
#  [  5 153]]
#
#
# ========================================
# Training model for: GE
# ========================================
# Test class distribution: 0s=44.68%, 1s=55.32%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GE] Test AUC: 0.4186 | F1: 0.3048 | MCC: -0.0988 | ACC: 0.4316
# Confusion matrix:
# [[101  46]
#  [141  41]]
#
#
# ========================================
# Training model for: GILD
# ========================================
# Test class distribution: 0s=48.02%, 1s=51.98%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GILD] Test AUC: 0.5732 | F1: 0.6840 | MCC: 0.0000 | ACC: 0.5198
# Confusion matrix:
# [[  0 158]
#  [  0 171]]
#
#
# ========================================
# Training model for: GME
# ========================================
# Test class distribution: 0s=54.10%, 1s=45.90%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GME] Test AUC: 0.5422 | F1: 0.5387 | MCC: 0.0984 | ACC: 0.5471
# Confusion matrix:
# [[93 85]
#  [64 87]]
#
#
# ========================================
# Training model for: GS
# ========================================
# Test class distribution: 0s=49.85%, 1s=50.15%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GS] Test AUC: 0.5167 | F1: 0.6112 | MCC: 0.0365 | ACC: 0.5167
# Confusion matrix:
# [[ 45 119]
#  [ 40 125]]
#
#
# ========================================
# Training model for: GSK
# ========================================
# Test class distribution: 0s=49.54%, 1s=50.46%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GSK] Test AUC: 0.5400 | F1: 0.6707 | MCC: 0.0000 | ACC: 0.5046
# Confusion matrix:
# [[  0 163]
#  [  0 166]]
#
#
# ========================================
# Training model for: HAL
# ========================================
# Test class distribution: 0s=48.02%, 1s=51.98%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [HAL] Test AUC: 0.4682 | F1: 0.6579 | MCC: 0.0334 | ACC: 0.5258
# Confusion matrix:
# [[ 23 135]
#  [ 21 150]]
#
#
# ========================================
# Training model for: HPQ
# ========================================
# Test class distribution: 0s=51.06%, 1s=48.94%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [HPQ] Test AUC: 0.5369 | F1: 0.6473 | MCC: -0.0428 | ACC: 0.4833
# Confusion matrix:
# [[  3 165]
#  [  5 156]]
#
#
# ========================================
# Training model for: HUM
# ========================================
# Test class distribution: 0s=48.02%, 1s=51.98%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [HUM] Test AUC: 0.5041 | F1: 0.6667 | MCC: 0.0230 | ACC: 0.5228
# Confusion matrix:
# [[ 15 143]
#  [ 14 157]]
#
#
# ========================================
# Training model for: KMB
# ========================================
# Test class distribution: 0s=49.85%, 1s=50.15%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [KMB] Test AUC: 0.4739 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.4985
# Confusion matrix:
# [[164   0]
#  [165   0]]
#
#
# ========================================
# Training model for: KO
# ========================================
# Test class distribution: 0s=48.33%, 1s=51.67%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [KO] Test AUC: 0.5496 | F1: 0.6682 | MCC: 0.1123 | ACC: 0.5532
# Confusion matrix:
# [[ 34 125]
#  [ 22 148]]
#
#
# ========================================
# Training model for: KSS
# ========================================
# Test class distribution: 0s=53.50%, 1s=46.50%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [KSS] Test AUC: 0.5205 | F1: 0.6349 | MCC: 0.0000 | ACC: 0.4650
# Confusion matrix:
# [[  0 176]
#  [  0 153]]
#
#
# ========================================
# Training model for: MRK
# ========================================
# Test class distribution: 0s=45.29%, 1s=54.71%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [MRK] Test AUC: 0.4515 | F1: 0.6197 | MCC: -0.0364 | ACC: 0.5076
# Confusion matrix:
# [[ 35 114]
#  [ 48 132]]
#
#
# ========================================
# Training model for: MS
# ========================================
# Test class distribution: 0s=52.28%, 1s=47.72%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [MS] Test AUC: 0.4868 | F1: 0.6461 | MCC: 0.0000 | ACC: 0.4772
# Confusion matrix:
# [[  0 172]
#  [  0 157]]
#
#
# ========================================
# Training model for: MU
# ========================================
# Test class distribution: 0s=53.19%, 1s=46.81%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [MU] Test AUC: 0.5112 | F1: 0.6387 | MCC: 0.0539 | ACC: 0.4772
# Confusion matrix:
# [[  5 170]
#  [  2 152]]
#
#
# ========================================
# Training model for: NEE
# ========================================
# Test class distribution: 0s=51.37%, 1s=48.63%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [NEE] Test AUC: 0.4433 | F1: 0.6544 | MCC: 0.0000 | ACC: 0.4863
# Confusion matrix:
# [[  0 169]
#  [  0 160]]
#
#
# ========================================
# Training model for: NEM
# ========================================
# Test class distribution: 0s=52.89%, 1s=47.11%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NEM] Test AUC: 0.5014 | F1: 0.6027 | MCC: -0.0593 | ACC: 0.4590
# Confusion matrix:
# [[ 16 158]
#  [ 20 135]]
#
#
# ========================================
# Training model for: NKE
# ========================================
# Test class distribution: 0s=51.06%, 1s=48.94%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [NKE] Test AUC: 0.4810 | F1: 0.6516 | MCC: -0.0799 | ACC: 0.4833
# Confusion matrix:
# [[  0 168]
#  [  2 159]]
#
#
# ========================================
# Training model for: NOC
# ========================================
# Test class distribution: 0s=47.11%, 1s=52.89%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [NOC] Test AUC: 0.4664 | F1: 0.6637 | MCC: 0.0500 | ACC: 0.5380
# Confusion matrix:
# [[ 27 128]
#  [ 24 150]]
#
#
# ========================================
# Training model for: NVS
# ========================================
# Test class distribution: 0s=48.33%, 1s=51.67%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [NVS] Test AUC: 0.5012 | F1: 0.6570 | MCC: -0.0722 | ACC: 0.4985
# Confusion matrix:
# [[  6 153]
#  [ 12 158]]
#
#
# ========================================
# Training model for: ORCL
# ========================================
# Test class distribution: 0s=44.68%, 1s=55.32%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [ORCL] Test AUC: 0.4921 | F1: 0.6497 | MCC: 0.0321 | ACC: 0.5410
# Confusion matrix:
# [[ 38 109]
#  [ 42 140]]
#
#
# ========================================
# Training model for: OXY
# ========================================
# Test class distribution: 0s=52.89%, 1s=47.11%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [OXY] Test AUC: 0.4968 | F1: 0.1136 | MCC: 0.0026 | ACC: 0.5258
# Confusion matrix:
# [[163  11]
#  [145  10]]
#
#
# ========================================
# Training model for: PANW
# ========================================
# Test class distribution: 0s=47.11%, 1s=52.89%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PANW] Test AUC: 0.5004 | F1: 0.6218 | MCC: -0.0283 | ACC: 0.5046
# Confusion matrix:
# [[ 32 123]
#  [ 40 134]]
#
#
# ========================================
# Training model for: PBR
# ========================================
# Test class distribution: 0s=46.81%, 1s=53.19%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [PBR] Test AUC: 0.4947 | F1: 0.6944 | MCC: 0.0000 | ACC: 0.5319
# Confusion matrix:
# [[  0 154]
#  [  0 175]]
#
#
# ========================================
# Training model for: PEP
# ========================================
# Test class distribution: 0s=49.85%, 1s=50.15%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [PEP] Test AUC: 0.4926 | F1: 0.6653 | MCC: 0.0215 | ACC: 0.5046
# Confusion matrix:
# [[  4 160]
#  [  3 162]]
#
#
# ========================================
# Training model for: PXD
# ========================================
# Test class distribution: 0s=48.63%, 1s=51.37%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [PXD] Test AUC: 0.4881 | F1: 0.5596 | MCC: -0.0445 | ACC: 0.4833
# Confusion matrix:
# [[ 51 109]
#  [ 61 108]]
#
#
# ========================================
# Training model for: QCOM
# ========================================
# Test class distribution: 0s=51.06%, 1s=48.94%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [QCOM] Test AUC: 0.4898 | F1: 0.6207 | MCC: 0.0149 | ACC: 0.4985
# Confusion matrix:
# [[ 29 139]
#  [ 26 135]]
#
#
# ========================================
# Training model for: SPWR
# ========================================
# Test class distribution: 0s=56.23%, 1s=43.77%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [SPWR] Test AUC: 0.5786 | F1: 0.4563 | MCC: 0.1009 | ACC: 0.5653
# Confusion matrix:
# [[126  59]
#  [ 84  60]]
#
#
# ========================================
# Training model for: T
# ========================================
# Test class distribution: 0s=49.85%, 1s=50.15%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [T] Test AUC: 0.5274 | F1: 0.6680 | MCC: 0.0000 | ACC: 0.5015
# Confusion matrix:
# [[  0 164]
#  [  0 165]]
#
#
# ========================================
# Training model for: TJX
# ========================================
# Test class distribution: 0s=49.24%, 1s=50.76%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TJX] Test AUC: 0.5247 | F1: 0.6734 | MCC: 0.0000 | ACC: 0.5076
# Confusion matrix:
# [[  0 162]
#  [  0 167]]
#
#
# ========================================
# Training model for: TM
# ========================================
# Test class distribution: 0s=47.11%, 1s=52.89%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TM] Test AUC: 0.4410 | F1: 0.4726 | MCC: -0.1158 | ACC: 0.4438
# Confusion matrix:
# [[64 91]
#  [92 82]]
#
#
# ========================================
# Training model for: TMUS
# ========================================
# Test class distribution: 0s=48.33%, 1s=51.67%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TMUS] Test AUC: 0.5083 | F1: 0.6748 | MCC: -0.0161 | ACC: 0.5137
# Confusion matrix:
# [[  3 156]
#  [  4 166]]
#
#
# ========================================
# Training model for: TRV
# ========================================
# Test class distribution: 0s=48.33%, 1s=51.67%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TRV] Test AUC: 0.5413 | F1: 0.6814 | MCC: 0.0000 | ACC: 0.5167
# Confusion matrix:
# [[  0 159]
#  [  0 170]]
#
#
# ========================================
# Training model for: TSM
# ========================================
# Test class distribution: 0s=54.41%, 1s=45.59%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TSM] Test AUC: 0.4821 | F1: 0.6186 | MCC: -0.0342 | ACC: 0.4529
# Confusion matrix:
# [[  3 176]
#  [  4 146]]
#
#
# ========================================
# Training model for: TSN
# ========================================
# Test class distribution: 0s=53.19%, 1s=46.81%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TSN] Test AUC: 0.5077 | F1: 0.6304 | MCC: 0.0422 | ACC: 0.4833
# Confusion matrix:
# [[ 14 161]
#  [  9 145]]
#
#
# ========================================
# Training model for: TXN
# ========================================
# Test class distribution: 0s=51.67%, 1s=48.33%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TXN] Test AUC: 0.4498 | F1: 0.4830 | MCC: -0.1022 | ACC: 0.4468
# Confusion matrix:
# [[ 62 108]
#  [ 74  85]]
#
#
# ========================================
# Training model for: USB
# ========================================
# Test class distribution: 0s=53.19%, 1s=46.81%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [USB] Test AUC: 0.4509 | F1: 0.6377 | MCC: 0.0000 | ACC: 0.4681
# Confusion matrix:
# [[  0 175]
#  [  0 154]]
#
#
# ========================================
# Training model for: V
# ========================================
# Test class distribution: 0s=47.72%, 1s=52.28%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [V] Test AUC: 0.5071 | F1: 0.6734 | MCC: -0.0718 | ACC: 0.5106
# Confusion matrix:
# [[  2 155]
#  [  6 166]]
#
#
# ========================================
# Training model for: VRTX
# ========================================
# Test class distribution: 0s=44.68%, 1s=55.32%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [VRTX] Test AUC: 0.4714 | F1: 0.7103 | MCC: 0.0370 | ACC: 0.5562
# Confusion matrix:
# [[  4 143]
#  [  3 179]]
#
#
# ========================================
# Training model for: WBA
# ========================================
# Test class distribution: 0s=55.62%, 1s=44.38%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [WBA] Test AUC: 0.5372 | F1: 0.5630 | MCC: 0.0564 | ACC: 0.5046
# Confusion matrix:
# [[ 61 122]
#  [ 41 105]]
#
#
# ========================================
# Training model for: WDC
# ========================================
# Test class distribution: 0s=50.76%, 1s=49.24%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [WDC] Test AUC: 0.4634 | F1: 0.4615 | MCC: -0.0640 | ACC: 0.4681
# Confusion matrix:
# [[79 88]
#  [87 75]]
#
#
# ========================================
# Training model for: WFC
# ========================================
# Test class distribution: 0s=48.48%, 1s=51.52%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [WFC] Test AUC: 0.5296 | F1: 0.4698 | MCC: 0.0441 | ACC: 0.5183
# Confusion matrix:
# [[100  59]
#  [ 99  70]]
#
#
# === Summary of all stocks ===
#    Symbol   Val_AUC    Val_F1   Val_MCC  Test_AUC   Test_F1  Test_MCC  \
# 0     AAL  0.539398  0.511327  0.071346  0.584869  0.637532  0.139746
# 64   SPWR  0.557479  0.434426  0.144102  0.578641  0.456274  0.100923
# 39   GILD  0.499059  0.663934  0.000000  0.573210  0.684000  0.000000
# 29   DISH  0.480984  0.290456 -0.096442  0.561929  0.500000  0.126456
# 27    DHI  0.534350  0.602041  0.041459  0.556217  0.645320  0.101091
# ..    ...       ...       ...       ...       ...       ...       ...
# 52    NEE  0.513160  0.685484  0.000000  0.443269  0.654397  0.000000
# 67     TM  0.542690  0.525680  0.037765  0.440971  0.472622 -0.115794
# 11   BIDU  0.452894  0.448052 -0.044367  0.439934  0.393220 -0.099884
# 3    ADBE  0.470689  0.674797  0.000000  0.434598  0.676056  0.000000
# 38     GE  0.472335  0.262009 -0.050019  0.418554  0.304833 -0.098806
#
#     Test_ACC    Test_0%    Test_1%
# 0   0.571429  48.328267  51.671733
# 64  0.565350  56.231003  43.768997
# 39  0.519757  48.024316  51.975684
# 29  0.568389  53.191489  46.808511
# 27  0.562310  45.896657  54.103343
# ..       ...        ...        ...
# 52  0.486322  51.367781  48.632219
# 67  0.443769  47.112462  52.887538
# 11  0.455927  55.319149  44.680851
# 3   0.510638  48.936170  51.063830
# 38  0.431611  44.680851  55.319149
#
# [79 rows x 10 columns]

# %%
print(results_df['Test_AUC'].mean())
print(results_df['Test_ACC'].mean())
print(results_df['Test_MCC'].mean())
# Out:
# 0.5006485723328307
# 0.5036942900497451
# 0.0009852159778564963

# %%
print(results_df['Test_AUC'].std())
print(results_df['Test_ACC'].std())
print(results_df['Test_MCC'].std())
# Out:
# 0.03601214698931073
# 0.031121050993559773
# 0.054334666757311065

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, matthews_corrcoef, confusion_matrix, roc_auc_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# === PARAMETERS ===
window_size = 20
feature_cols = ['open_logret', 'high_logret', 'low_logret', 'close_logret', 'volume_logret']
target = 'target_binary'
l2_value = 1e-4
batch_size = 64
epochs = 50
learning_rate = 0.001

# Results dataframe
results = []

# === LOOP THROUGH EACH STOCK ===
for symbol in df['Stock_symbol'].unique():
    print(f"\n{'='*40}\nTraining model for: {symbol}\n{'='*40}")

    # Subset dataframe
    df_symbol = df[df['Stock_symbol'] == symbol].copy()
    price_cols = ['open', 'high', 'low', 'close', 'volume']
    for col in price_cols:
      df_symbol[f'{col}_logret'] = np.log(df_symbol[col]) - np.log(df_symbol[col].shift(1))
    df_symbol.dropna(inplace=True)

    # Define time splits
    train = df_symbol.loc['2014-01-01':'2021-03-29']
    val = df_symbol.loc['2021-03-30':'2022-07-28']
    test = df_symbol.loc['2022-07-29':'2023-12-01']

    # Skip if insufficient data
    if len(train) < window_size * 2 or len(test) < window_size:
        print(f"Not enough data for {symbol}, skipping.")
        continue

    # Create sequences (your sequences() function should return numpy arrays)
    X_train, y_train = sequences(train, window_size=window_size, feature_cols=feature_cols, target=target)
    X_val, y_val = sequences(val, window_size=window_size, feature_cols=feature_cols, target=target)
    X_test, y_test = sequences(test, window_size=window_size, feature_cols=feature_cols, target=target)

    X_train = np.array(X_train); y_train = np.array(y_train)
    X_val = np.array(X_val); y_val = np.array(y_val)
    X_test = np.array(X_test); y_test = np.array(y_test)

    # Replace NaNs and normalize
    for X in [X_train, X_val, X_test]:
        np.nan_to_num(X, nan=0.0, posinf=0.0, neginf=0.0, copy=False)

    mean = np.mean(X_train, axis=(0,1))
    std = np.std(X_train, axis=(0,1))
    std[std == 0] = 1e-8

    # X_train_norm = (X_train - mean) / std
    # X_val_norm = (X_val - mean) / std
    # X_test_norm = (X_test - mean) / std

    # Print class distribution for test
    unique, counts = np.unique(y_test, return_counts=True)
    dist = dict(zip(unique, counts))
    total = counts.sum()
    pct_0 = 100 * dist.get(0, 0) / total
    pct_1 = 100 * dist.get(1, 0) / total
    print(f"Test class distribution: 0s={pct_0:.2f}%, 1s={pct_1:.2f}%")

    # === Model ===
    model = Sequential([
        Input(shape=(window_size, len(feature_cols))),
        Conv1D(filters=16, kernel_size=3, strides=1, activation='relu', padding='same'),
        BatchNormalization(),
        Conv1D(filters=8, kernel_size=3, strides=1, activation='relu', padding='same'),
        BatchNormalization(),
        LSTM(16),
        Dropout(0.1),
        Dense(16, activation='relu'),
        Dropout(0.2),
        Dense(1, activation='sigmoid', kernel_regularizer=l2(l2_value))
    ])

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC', 'accuracy'])
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # === Train ===
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stop],
        verbose=0
    )

    # === Evaluation ===
    y_val_pred_prob = model.predict(X_val)
    y_val_pred = (y_val_pred_prob > 0.5).astype(int)

    y_test_pred_prob = model.predict(X_test)
    y_test_pred = (y_test_pred_prob > 0.5).astype(int)

    # Validation metrics
    val_auc = roc_auc_score(y_val, y_val_pred_prob)
    val_f1 = f1_score(y_val, y_val_pred)
    val_mcc = matthews_corrcoef(y_val, y_val_pred)

    # Test metrics
    test_auc = roc_auc_score(y_test, y_test_pred_prob)
    test_f1 = f1_score(y_test, y_test_pred)
    test_mcc = matthews_corrcoef(y_test, y_test_pred)
    test_acc = np.mean(y_test_pred.flatten() == y_test.flatten())
    test_cm = confusion_matrix(y_test, y_test_pred)

    print(f"[{symbol}] Test AUC: {test_auc:.4f} | F1: {test_f1:.4f} | MCC: {test_mcc:.4f} | ACC: {test_acc:.4f}")
    print(f"Confusion matrix:\n{test_cm}\n")

    # Save results
    results.append({
        'Symbol': symbol,
        'Val_AUC': val_auc,
        'Val_F1': val_f1,
        'Val_MCC': val_mcc,
        'Test_AUC': test_auc,
        'Test_F1': test_f1,
        'Test_MCC': test_mcc,
        'Test_ACC': test_acc,
        'Test_0%': pct_0,
        'Test_1%': pct_1
    })

# === SAVE ALL RESULTS ===
results_df = pd.DataFrame(results)
results_df.to_csv('model_results_per_stock_log_window20_batch64.csv', index=False)
print("\n=== Summary of all stocks ===")
print(results_df.sort_values('Test_AUC', ascending=False))
# Out:
# ========================================
# Training model for: AAL
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [AAL] Test AUC: 0.5036 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.4828
# Confusion matrix:
# [[154   0]
#  [165   0]]
#
#
# ========================================
# Training model for: ABBV
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ABBV] Test AUC: 0.5275 | F1: 0.6791 | MCC: -0.0542 | ACC: 0.5141
# Confusion matrix:
# [[  0 154]
#  [  1 164]]
#
#
# ========================================
# Training model for: ACN
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ACN] Test AUC: 0.4912 | F1: 0.6818 | MCC: 0.0000 | ACC: 0.5172
# Confusion matrix:
# [[  0 154]
#  [  0 165]]
#
#
# ========================================
# Training model for: ADBE
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ADBE] Test AUC: 0.5013 | F1: 0.6845 | MCC: 0.0000 | ACC: 0.5204
# Confusion matrix:
# [[  0 153]
#  [  0 166]]
#
#
# ========================================
# Training model for: AEO
# ========================================
# Test class distribution: 0s=42.95%, 1s=57.05%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [AEO] Test AUC: 0.4560 | F1: 0.7265 | MCC: 0.0000 | ACC: 0.5705
# Confusion matrix:
# [[  0 137]
#  [  0 182]]
#
#
# ========================================
# Training model for: AIG
# ========================================
# Test class distribution: 0s=44.51%, 1s=55.49%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [AIG] Test AUC: 0.5137 | F1: 0.7137 | MCC: 0.0000 | ACC: 0.5549
# Confusion matrix:
# [[  0 142]
#  [  0 177]]
#
#
# ========================================
# Training model for: ALK
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ALK] Test AUC: 0.4948 | F1: 0.4415 | MCC: -0.0453 | ACC: 0.4765
# Confusion matrix:
# [[86 71]
#  [96 66]]
#
#
# ========================================
# Training model for: AMGN
# ========================================
# Test class distribution: 0s=54.86%, 1s=45.14%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [AMGN] Test AUC: 0.4624 | F1: 0.6220 | MCC: 0.0000 | ACC: 0.4514
# Confusion matrix:
# [[  0 175]
#  [  0 144]]
#
#
# ========================================
# Training model for: AMT
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [AMT] Test AUC: 0.3952 | F1: 0.6483 | MCC: 0.0000 | ACC: 0.4796
# Confusion matrix:
# [[  0 166]
#  [  0 153]]
#
#
# ========================================
# Training model for: BABA
# ========================================
# Test class distribution: 0s=54.55%, 1s=45.45%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [BABA] Test AUC: 0.4824 | F1: 0.6263 | MCC: 0.0512 | ACC: 0.4577
# Confusion matrix:
# [[  1 173]
#  [  0 145]]
#
#
# ========================================
# Training model for: BHP
# ========================================
# Test class distribution: 0s=49.53%, 1s=50.47%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BHP] Test AUC: 0.4682 | F1: 0.6708 | MCC: 0.0000 | ACC: 0.5047
# Confusion matrix:
# [[  0 158]
#  [  0 161]]
#
#
# ========================================
# Training model for: BIDU
# ========================================
# Test class distribution: 0s=55.49%, 1s=44.51%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BIDU] Test AUC: 0.4676 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.5549
# Confusion matrix:
# [[177   0]
#  [142   0]]
#
#
# ========================================
# Training model for: BIIB
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BIIB] Test AUC: 0.4866 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.5266
# Confusion matrix:
# [[168   0]
#  [151   0]]
#
#
# ========================================
# Training model for: BSX
# ========================================
# Test class distribution: 0s=46.39%, 1s=53.61%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BSX] Test AUC: 0.4925 | F1: 0.6980 | MCC: 0.0000 | ACC: 0.5361
# Confusion matrix:
# [[  0 148]
#  [  0 171]]
#
#
# ========================================
# Training model for: BX
# ========================================
# Test class distribution: 0s=47.34%, 1s=52.66%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [BX] Test AUC: 0.5303 | F1: 0.6899 | MCC: 0.0000 | ACC: 0.5266
# Confusion matrix:
# [[  0 151]
#  [  0 168]]
#
#
# ========================================
# Training model for: CAT
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CAT] Test AUC: 0.4948 | F1: 0.6623 | MCC: 0.0172 | ACC: 0.5110
# Confusion matrix:
# [[ 10 147]
#  [  9 153]]
#
#
# ========================================
# Training model for: CI
# ========================================
# Test class distribution: 0s=46.08%, 1s=53.92%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CI] Test AUC: 0.4944 | F1: 0.7006 | MCC: 0.0000 | ACC: 0.5392
# Confusion matrix:
# [[  0 147]
#  [  0 172]]
#
#
# ========================================
# Training model for: CMCSA
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CMCSA] Test AUC: 0.4900 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: CMG
# ========================================
# Test class distribution: 0s=43.89%, 1s=56.11%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CMG] Test AUC: 0.4564 | F1: 0.7189 | MCC: 0.0000 | ACC: 0.5611
# Confusion matrix:
# [[  0 140]
#  [  0 179]]
#
#
# ========================================
# Training model for: COP
# ========================================
# Test class distribution: 0s=50.47%, 1s=49.53%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [COP] Test AUC: 0.4663 | F1: 0.1075 | MCC: -0.0857 | ACC: 0.4796
# Confusion matrix:
# [[143  18]
#  [148  10]]
#
#
# ========================================
# Training model for: COST
# ========================================
# Test class distribution: 0s=45.77%, 1s=54.23%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [COST] Test AUC: 0.4911 | F1: 0.7033 | MCC: 0.0000 | ACC: 0.5423
# Confusion matrix:
# [[  0 146]
#  [  0 173]]
#
#
# ========================================
# Training model for: CRM
# ========================================
# Test class distribution: 0s=47.02%, 1s=52.98%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CRM] Test AUC: 0.5442 | F1: 0.0345 | MCC: 0.0178 | ACC: 0.4734
# Confusion matrix:
# [[148   2]
#  [166   3]]
#
#
# ========================================
# Training model for: CSX
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [CSX] Test AUC: 0.5553 | F1: 0.5141 | MCC: 0.0299 | ACC: 0.5141
# Confusion matrix:
# [[82 84]
#  [71 82]]
#
#
# ========================================
# Training model for: D
# ========================================
# Test class distribution: 0s=49.53%, 1s=50.47%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [D] Test AUC: 0.5434 | F1: 0.4093 | MCC: 0.0481 | ACC: 0.5204
# Confusion matrix:
# [[113  45]
#  [108  53]]
#
#
# ========================================
# Training model for: DB
# ========================================
# Test class distribution: 0s=42.95%, 1s=57.05%
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DB] Test AUC: 0.4372 | F1: 0.2155 | MCC: -0.0614 | ACC: 0.4295
# Confusion matrix:
# [[112  25]
#  [157  25]]
#
#
# ========================================
# Training model for: DE
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DE] Test AUC: 0.5053 | F1: 0.6845 | MCC: 0.0000 | ACC: 0.5204
# Confusion matrix:
# [[  0 153]
#  [  0 166]]
#
#
# ========================================
# Training model for: DFS
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DFS] Test AUC: 0.4747 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: DHI
# ========================================
# Test class distribution: 0s=45.45%, 1s=54.55%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DHI] Test AUC: 0.5150 | F1: 0.7059 | MCC: 0.0000 | ACC: 0.5455
# Confusion matrix:
# [[  0 145]
#  [  0 174]]
#
#
# ========================================
# Training model for: DHR
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [DHR] Test AUC: 0.4750 | F1: 0.6845 | MCC: 0.0000 | ACC: 0.5204
# Confusion matrix:
# [[  0 153]
#  [  0 166]]
#
#
# ========================================
# Training model for: DISH
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DISH] Test AUC: 0.4816 | F1: 0.0132 | MCC: 0.0595 | ACC: 0.5329
# Confusion matrix:
# [[169   0]
#  [149   1]]
#
#
# ========================================
# Training model for: DPZ
# ========================================
# Test class distribution: 0s=50.16%, 1s=49.84%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [DPZ] Test AUC: 0.4484 | F1: 0.6653 | MCC: 0.0000 | ACC: 0.4984
# Confusion matrix:
# [[  0 160]
#  [  0 159]]
#
#
# ========================================
# Training model for: DUK
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [DUK] Test AUC: 0.4877 | F1: 0.6736 | MCC: 0.0000 | ACC: 0.5078
# Confusion matrix:
# [[  0 157]
#  [  0 162]]
#
#
# ========================================
# Training model for: EA
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [EA] Test AUC: 0.5560 | F1: 0.6845 | MCC: 0.0000 | ACC: 0.5204
# Confusion matrix:
# [[  0 153]
#  [  0 166]]
#
#
# ========================================
# Training model for: EBAY
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [EBAY] Test AUC: 0.4630 | F1: 0.6540 | MCC: 0.0000 | ACC: 0.4859
# Confusion matrix:
# [[  0 164]
#  [  0 155]]
#
#
# ========================================
# Training model for: ENB
# ========================================
# Test class distribution: 0s=51.10%, 1s=48.90%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ENB] Test AUC: 0.5226 | F1: 0.4516 | MCC: 0.0367 | ACC: 0.5204
# Confusion matrix:
# [[103  60]
#  [ 93  63]]
#
#
# ========================================
# Training model for: EOG
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [EOG] Test AUC: 0.5095 | F1: 0.6540 | MCC: 0.0000 | ACC: 0.4859
# Confusion matrix:
# [[  0 164]
#  [  0 155]]
#
#
# ========================================
# Training model for: FDX
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [FDX] Test AUC: 0.4607 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[164   0]
#  [155   0]]
#
#
# ========================================
# Training model for: FSLR
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [FSLR] Test AUC: 0.5821 | F1: 0.6484 | MCC: 0.1079 | ACC: 0.5172
# Confusion matrix:
# [[ 23 143]
#  [ 11 142]]
#
#
# ========================================
# Training model for: GE
# ========================================
# Test class distribution: 0s=44.20%, 1s=55.80%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GE] Test AUC: 0.4798 | F1: 0.0321 | MCC: -0.0771 | ACC: 0.4326
# Confusion matrix:
# [[135   6]
#  [175   3]]
#
#
# ========================================
# Training model for: GILD
# ========================================
# Test class distribution: 0s=47.34%, 1s=52.66%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [GILD] Test AUC: 0.5266 | F1: 0.1726 | MCC: 0.0377 | ACC: 0.4890
# Confusion matrix:
# [[139  12]
#  [151  17]]
#
#
# ========================================
# Training model for: GME
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [GME] Test AUC: 0.5506 | F1: 0.0000 | MCC: -0.0748 | ACC: 0.5235
# Confusion matrix:
# [[167   2]
#  [150   0]]
#
#
# ========================================
# Training model for: GS
# ========================================
# Test class distribution: 0s=49.53%, 1s=50.47%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [GS] Test AUC: 0.4827 | F1: 0.6708 | MCC: 0.0000 | ACC: 0.5047
# Confusion matrix:
# [[  0 158]
#  [  0 161]]
#
#
# ========================================
# Training model for: GSK
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [GSK] Test AUC: 0.5269 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: HAL
# ========================================
# Test class distribution: 0s=47.65%, 1s=52.35%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [HAL] Test AUC: 0.4610 | F1: 0.6872 | MCC: 0.0000 | ACC: 0.5235
# Confusion matrix:
# [[  0 152]
#  [  0 167]]
#
#
# ========================================
# Training model for: HPQ
# ========================================
# Test class distribution: 0s=50.47%, 1s=49.53%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [HPQ] Test AUC: 0.5062 | F1: 0.6625 | MCC: 0.0000 | ACC: 0.4953
# Confusion matrix:
# [[  0 161]
#  [  0 158]]
#
#
# ========================================
# Training model for: HUM
# ========================================
# Test class distribution: 0s=48.28%, 1s=51.72%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [HUM] Test AUC: 0.4660 | F1: 0.6818 | MCC: 0.0000 | ACC: 0.5172
# Confusion matrix:
# [[  0 154]
#  [  0 165]]
#
#
# ========================================
# Training model for: KMB
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [KMB] Test AUC: 0.5003 | F1: 0.6723 | MCC: 0.0545 | ACC: 0.5172
# Confusion matrix:
# [[  7 150]
#  [  4 158]]
#
#
# ========================================
# Training model for: KO
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [KO] Test AUC: 0.4974 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: KSS
# ========================================
# Test class distribution: 0s=53.29%, 1s=46.71%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [KSS] Test AUC: 0.5155 | F1: 0.6368 | MCC: 0.0000 | ACC: 0.4671
# Confusion matrix:
# [[  0 170]
#  [  0 149]]
#
#
# ========================================
# Training model for: MRK
# ========================================
# Test class distribution: 0s=44.83%, 1s=55.17%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [MRK] Test AUC: 0.4871 | F1: 0.6996 | MCC: -0.0394 | ACC: 0.5423
# Confusion matrix:
# [[  3 140]
#  [  6 170]]
#
#
# ========================================
# Training model for: MS
# ========================================
# Test class distribution: 0s=52.04%, 1s=47.96%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [MS] Test AUC: 0.4184 | F1: 0.6483 | MCC: 0.0000 | ACC: 0.4796
# Confusion matrix:
# [[  0 166]
#  [  0 153]]
#
#
# ========================================
# Training model for: MU
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [MU] Test AUC: 0.5713 | F1: 0.6426 | MCC: 0.0000 | ACC: 0.4734
# Confusion matrix:
# [[  0 168]
#  [  0 151]]
#
#
# ========================================
# Training model for: NEE
# ========================================
# Test class distribution: 0s=51.10%, 1s=48.90%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [NEE] Test AUC: 0.4958 | F1: 0.6568 | MCC: 0.0000 | ACC: 0.4890
# Confusion matrix:
# [[  0 163]
#  [  0 156]]
#
#
# ========================================
# Training model for: NEM
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NEM] Test AUC: 0.5010 | F1: 0.6397 | MCC: 0.0000 | ACC: 0.4702
# Confusion matrix:
# [[  0 169]
#  [  0 150]]
#
#
# ========================================
# Training model for: NKE
# ========================================
# Test class distribution: 0s=51.10%, 1s=48.90%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NKE] Test AUC: 0.4496 | F1: 0.6554 | MCC: -0.0017 | ACC: 0.4890
# Confusion matrix:
# [[  1 162]
#  [  1 155]]
#
#
# ========================================
# Training model for: NOC
# ========================================
# Test class distribution: 0s=47.02%, 1s=52.98%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NOC] Test AUC: 0.4874 | F1: 0.6926 | MCC: 0.0000 | ACC: 0.5298
# Confusion matrix:
# [[  0 150]
#  [  0 169]]
#
#
# ========================================
# Training model for: NVS
# ========================================
# Test class distribution: 0s=47.65%, 1s=52.35%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [NVS] Test AUC: 0.4153 | F1: 0.6791 | MCC: -0.0930 | ACC: 0.5141
# Confusion matrix:
# [[  0 152]
#  [  3 164]]
#
#
# ========================================
# Training model for: ORCL
# ========================================
# Test class distribution: 0s=43.89%, 1s=56.11%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [ORCL] Test AUC: 0.5757 | F1: 0.7189 | MCC: 0.0000 | ACC: 0.5611
# Confusion matrix:
# [[  0 140]
#  [  0 179]]
#
#
# ========================================
# Training model for: OXY
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [OXY] Test AUC: 0.4925 | F1: 0.6426 | MCC: 0.0000 | ACC: 0.4734
# Confusion matrix:
# [[  0 168]
#  [  0 151]]
#
#
# ========================================
# Training model for: PANW
# ========================================
# Test class distribution: 0s=46.71%, 1s=53.29%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PANW] Test AUC: 0.4989 | F1: 0.6953 | MCC: 0.0000 | ACC: 0.5329
# Confusion matrix:
# [[  0 149]
#  [  0 170]]
#
#
# ========================================
# Training model for: PBR
# ========================================
# Test class distribution: 0s=47.65%, 1s=52.35%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PBR] Test AUC: 0.4702 | F1: 0.6872 | MCC: 0.0000 | ACC: 0.5235
# Confusion matrix:
# [[  0 152]
#  [  0 167]]
#
#
# ========================================
# Training model for: PEP
# ========================================
# Test class distribution: 0s=49.84%, 1s=50.16%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PEP] Test AUC: 0.5297 | F1: 0.6681 | MCC: 0.0000 | ACC: 0.5016
# Confusion matrix:
# [[  0 159]
#  [  0 160]]
#
#
# ========================================
# Training model for: PXD
# ========================================
# Test class distribution: 0s=49.22%, 1s=50.78%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [PXD] Test AUC: 0.5190 | F1: 0.6708 | MCC: -0.0552 | ACC: 0.5047
# Confusion matrix:
# [[  0 157]
#  [  1 161]]
#
#
# ========================================
# Training model for: QCOM
# ========================================
# Test class distribution: 0s=50.78%, 1s=49.22%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [QCOM] Test AUC: 0.4651 | F1: 0.6179 | MCC: -0.0069 | ACC: 0.4922
# Confusion matrix:
# [[ 26 136]
#  [ 26 131]]
#
#
# ========================================
# Training model for: SPWR
# ========================================
# Test class distribution: 0s=55.80%, 1s=44.20%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [SPWR] Test AUC: 0.4701 | F1: 0.3158 | MCC: 0.0454 | ACC: 0.5517
# Confusion matrix:
# [[143  35]
#  [108  33]]
#
#
# ========================================
# Training model for: T
# ========================================
# Test class distribution: 0s=49.84%, 1s=50.16%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [T] Test AUC: 0.4928 | F1: 0.6681 | MCC: 0.0000 | ACC: 0.5016
# Confusion matrix:
# [[  0 159]
#  [  0 160]]
#
#
# ========================================
# Training model for: TJX
# ========================================
# Test class distribution: 0s=48.90%, 1s=51.10%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TJX] Test AUC: 0.4988 | F1: 0.6763 | MCC: 0.0000 | ACC: 0.5110
# Confusion matrix:
# [[  0 156]
#  [  0 163]]
#
#
# ========================================
# Training model for: TM
# ========================================
# Test class distribution: 0s=46.39%, 1s=53.61%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TM] Test AUC: 0.4481 | F1: 0.6980 | MCC: 0.0000 | ACC: 0.5361
# Confusion matrix:
# [[  0 148]
#  [  0 171]]
#
#
# ========================================
# Training model for: TMUS
# ========================================
# Test class distribution: 0s=47.96%, 1s=52.04%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [TMUS] Test AUC: 0.5216 | F1: 0.0455 | MCC: -0.0433 | ACC: 0.4734
# Confusion matrix:
# [[147   6]
#  [162   4]]
#
#
# ========================================
# Training model for: TRV
# ========================================
# Test class distribution: 0s=48.59%, 1s=51.41%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [TRV] Test AUC: 0.5095 | F1: 0.6791 | MCC: 0.0000 | ACC: 0.5141
# Confusion matrix:
# [[  0 155]
#  [  0 164]]
#
#
# ========================================
# Training model for: TSM
# ========================================
# Test class distribution: 0s=54.23%, 1s=45.77%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TSM] Test AUC: 0.5390 | F1: 0.6280 | MCC: 0.0000 | ACC: 0.4577
# Confusion matrix:
# [[  0 173]
#  [  0 146]]
#
#
# ========================================
# Training model for: TSN
# ========================================
# Test class distribution: 0s=52.98%, 1s=47.02%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [TSN] Test AUC: 0.5054 | F1: 0.4336 | MCC: -0.0248 | ACC: 0.4922
# Confusion matrix:
# [[95 74]
#  [88 62]]
#
#
# ========================================
# Training model for: TXN
# ========================================
# Test class distribution: 0s=51.41%, 1s=48.59%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [TXN] Test AUC: 0.4747 | F1: 0.6540 | MCC: 0.0000 | ACC: 0.4859
# Confusion matrix:
# [[  0 164]
#  [  0 155]]
#
#
# ========================================
# Training model for: USB
# ========================================
# Test class distribution: 0s=52.66%, 1s=47.34%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [USB] Test AUC: 0.4853 | F1: 0.6376 | MCC: 0.0224 | ACC: 0.4796
# Confusion matrix:
# [[  7 161]
#  [  5 146]]
#
#
# ========================================
# Training model for: V
# ========================================
# Test class distribution: 0s=47.34%, 1s=52.66%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [V] Test AUC: 0.4985 | F1: 0.6899 | MCC: 0.0000 | ACC: 0.5266
# Confusion matrix:
# [[  0 151]
#  [  0 168]]
#
#
# ========================================
# Training model for: VRTX
# ========================================
# Test class distribution: 0s=44.20%, 1s=55.80%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [VRTX] Test AUC: 0.5037 | F1: 0.6860 | MCC: 0.0491 | ACC: 0.5580
# Confusion matrix:
# [[ 24 117]
#  [ 24 154]]
#
#
# ========================================
# Training model for: WBA
# ========================================
# Test class distribution: 0s=55.49%, 1s=44.51%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [WBA] Test AUC: 0.4617 | F1: 0.6038 | MCC: 0.0487 | ACC: 0.4734
# Confusion matrix:
# [[ 23 154]
#  [ 14 128]]
#
#
# ========================================
# Training model for: WDC
# ========================================
# Test class distribution: 0s=50.16%, 1s=49.84%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [WDC] Test AUC: 0.5087 | F1: 0.6653 | MCC: 0.0000 | ACC: 0.4984
# Confusion matrix:
# [[  0 160]
#  [  0 159]]
#
#
# ========================================
# Training model for: WFC
# ========================================
# Test class distribution: 0s=48.43%, 1s=51.57%
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [WFC] Test AUC: 0.5446 | F1: 0.0000 | MCC: 0.0000 | ACC: 0.4843
# Confusion matrix:
# [[154   0]
#  [164   0]]
#
#
# === Summary of all stocks ===
#    Symbol   Val_AUC    Val_F1   Val_MCC  Test_AUC   Test_F1  Test_MCC  \
# 37   FSLR  0.497837  0.643172 -0.051988  0.582093  0.648402  0.107918
# 57   ORCL  0.489434  0.652452  0.000000  0.575718  0.718876  0.000000
# 51     MU  0.549994  0.691511  0.000000  0.571350  0.642553  0.000000
# 32     EA  0.528860  0.677824  0.000000  0.555989  0.684536  0.000000
# 22    CSX  0.476257  0.464646 -0.003722  0.555339  0.514107  0.029924
# ..    ...       ...       ...       ...       ...       ...       ...
# 67     TM  0.480763  0.688797  0.000000  0.448080  0.697959  0.000000
# 24     DB  0.476522  0.130435 -0.040600  0.437234  0.215517 -0.061432
# 50     MS  0.529092  0.675052  0.000000  0.418419  0.648305  0.000000
# 56    NVS  0.440304  0.670886  0.001010  0.415262  0.679089 -0.092957
# 8     AMT  0.506516  0.680585  0.000000  0.395228  0.648305  0.000000
#
#     Test_ACC    Test_0%    Test_1%
# 37  0.517241  52.037618  47.962382
# 57  0.561129  43.887147  56.112853
# 51  0.473354  52.664577  47.335423
# 32  0.520376  47.962382  52.037618
# 22  0.514107  52.037618  47.962382
# ..       ...        ...        ...
# 67  0.536050  46.394984  53.605016
# 24  0.429467  42.946708  57.053292
# 50  0.479624  52.037618  47.962382
# 56  0.514107  47.648903  52.351097
# 8   0.479624  52.037618  47.962382
#
# [79 rows x 10 columns]

# %%
print(results_df['Test_AUC'].mean())
print(results_df['Test_ACC'].mean())
print(results_df['Test_MCC'].mean())
# Out:
# 0.49469546529336217
# 0.5071022688278067
# -0.00046387905925959424

# %%
from google.colab import files

files.download('model_results_per_stock_log_window20_batch64.csv')
